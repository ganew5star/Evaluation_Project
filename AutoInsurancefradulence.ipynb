# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dx=pd.read_csv('Automobile_insurance_fraud.csv')
dx
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df=pd.DataFrame(dx)
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
df['police_report_available']=df['police_report_available'].replace("?",np.nan)

# %%
mode_police_report_available=df['police_report_available'].mode()[0]
df['police_report_available']=df['police_report_available'].fillna(mode_police_report_available)

# %% [markdown]
# # Observation:
#     Size of the dataset is 1000 rows and 40 features
#     Overall 19 features which has numeric types and 21 object types
#     there is no null value present in the dataset.

# %% [markdown]
# # EDA

# %% [markdown]
# # UniVariate

# %%
obj=[]
for i in df.columns:
    if df[i].dtypes==object:
        obj.append(i)

# %%
num=[]
for j in df.columns:
    if df[j].dtypes!=object:
        num.append(j)

# %%
obj
# Out:
# ['policy_bind_date',
#  'policy_state',
#  'policy_csl',
#  'insured_sex',
#  'insured_education_level',
#  'insured_occupation',
#  'insured_hobbies',
#  'insured_relationship',
#  'incident_date',
#  'incident_type',
#  'collision_type',
#  'incident_severity',
#  'authorities_contacted',
#  'incident_state',
#  'incident_city',
#  'incident_location',
#  'property_damage',
#  'police_report_available',
#  'auto_make',
#  'auto_model',
#  'fraud_reported']

# %%
num
# Out:
# ['months_as_customer',
#  'age',
#  'policy_number',
#  'policy_deductable',
#  'policy_annual_premium',
#  'umbrella_limit',
#  'insured_zip',
#  'capital-gains',
#  'capital-loss',
#  'incident_hour_of_the_day',
#  'number_of_vehicles_involved',
#  'bodily_injuries',
#  'witnesses',
#  'total_claim_amount',
#  'injury_claim',
#  'property_claim',
#  'vehicle_claim',
#  'auto_year',
#  '_c39']

# %%
df[df['collision_type']=='?']
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 1                   228   42         342868       27-06-2006           IN
# 4                   228   44         367455       06-06-2014           IL
# 13                  121   34         626808       26-10-2012           OH
# 26                  257   43         863236       20-09-1990           IN
# 27                  202   34         608513       18-07-2002           IN
# ..                  ...  ...            ...              ...          ...
# 964                 163   37         390256       25-11-2009           IN
# 969                 398   55         844062       25-05-1990           OH
# 983                  17   39         774895       28-10-2006           IL
# 994                 141   30         681486       24-03-2007           IN
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df['collision_type']=df['collision_type'].replace("?",np.nan)

# %%
mode_collision_type=df['collision_type'].mode()[0]
df['collision_type']=df['collision_type'].fillna(mode_collision_type)

# %%
df['property_damage']=df['property_damage'].replace("?",np.nan)

# %%
mode_collision_type=df['property_damage'].mode()[0]
df['property_damage']=df['property_damage'].fillna(mode_collision_type)

# %%
for i in obj:
    plt.figure(figsize=(10,4))
    sns.countplot(x=df[i])
    plt.title(f'countplot of the features{i}')
    plt.xticks(rotation=40)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17816\1352755303.py in <module>
#       4     plt.title(f'countplot of the features{i}')
#       5     plt.xticks(rotation=40)
# ----> 6     plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     387     """
#     388     _warn_if_gui_out_of_main_thread()
# --> 389     return _get_backend_mod().show(*args, **kwargs)
#     390
#     391
#
# ~\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %% [markdown]
# # Observation:
#     Policy_state is of the state OH,IN and IL
#     policy_csl 250/500,100/300,500/1000.
#     insured relationship is higher in own-child category,followed by other-relative and husband at next to it.
#     The incident_type is Single Vehicle Collision which is compared with Multi-Vehicle Collision and Vehicle Theft and parked car.
#     Side Collision, Rear Collision and Front Collision is upto it in the collision type dataset.
#     Most of the part of incident_severity is Minor Damage and Major Damage respectively.
#     Authorities_contacted through in frequency of Police and followed by Fire.
#     Property_damage in more of NO under the category.

# %%
for j in num:
    plt.figure(figsize=(10,4))
    sns.histplot(x=df[j])
    plt.title(f'countplot of the features{j}')
    plt.xticks(rotation=40)
    plt.show()

# %%
df.describe()

# %% [markdown]
# # Observation:
#     Data distribution is widely spread in policy number and capital-gains.
#     Skewness present in all the features
#     Outliers also present in the some of features.

# %% [markdown]
# # BiVariate:

# %%
for i in obj:
    plt.figure(figsize=(10,4))
    sns.countplot(x=df[i],hue=df['fraud_reported'])
    plt.xticks(rotation=40)
    plt.show()

# %% [markdown]
# # Observation:
#     More number of fraudlent are lies in other-relative.
#     Single Vehicle Collision and Multi-Vehicle collision are of incident types happened in fraudlent report.
#     Rear Collision are basically as good type in collision_type of the dataset.
#     Major Damage are the incident_severity present in the types of it from fraudlent report.
#     Customer who contacted authorities of Police, Fire and others when it was accident taken place.
#     Most of the incident taken place in Sc and NY repespectively.
#     City of Arlington and Columbus are of the city which is fraudlent taken place.
#     property damages are occured in NO of the processs and Yes of the others
#     Ford and Audi are the types of makes which auto_make occured.
#     RAM is the highest reaches of models compared with others.

# %% [markdown]
# # Multivariate:

# %%
sns.pairplot(df)

# %%
df.columns

# %%
df1=df[['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
       'policy_state', 'policy_csl', 'policy_deductable',
       'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
       'insured_education_level', 'insured_occupation', 'insured_hobbies',
       'insured_relationship', 'capital-gains', 'capital-loss',
       'incident_date', 'incident_type', 'collision_type', 'incident_severity',
       'authorities_contacted', 'incident_state', 'incident_city',
       'incident_location', 'incident_hour_of_the_day',
       'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
       'witnesses', 'police_report_available', 'total_claim_amount',
       'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
       'auto_model', 'auto_year', 'fraud_reported', #'_c39'
      ]]

# %%
obj

# %%
df1.policy_state.unique()

# %%
df1.policy_state=df1.policy_state.map({'OH':1, 'IN':2, 'IL':3})

# %%
df1.policy_state.unique()

# %%
df1.policy_csl.unique()

# %%
df1.policy_csl=df1.policy_csl.map({'250/500':1, '100/300':2, '500/1000':3})

# %%
df1.policy_csl.unique()

# %%
df1.insured_sex.unique()

# %%
df1.insured_sex=df1.insured_sex.map({'MALE':1, 'FEMALE':2})

# %%
df1.insured_sex.unique()

# %%
df1.insured_education_level.unique()

# %%
df1.insured_education_level=df1.insured_education_level.map({'MD':1, 'PhD':2, 'Associate':3, 'Masters':4, 'High School':5, 'College':6,'JD':7})

# %%
df1.insured_occupation.unique()

# %%
df1.insured_occupation=df1.insured_occupation.map({'craft-repair':1, 'machine-op-inspct':2, 'sales':3, 'armed-forces':4,
       'tech-support':5, 'prof-specialty':6, 'other-service':7,
       'priv-house-serv':8, 'exec-managerial':9, 'protective-serv':10,
       'transport-moving':11, 'handlers-cleaners':12, 'adm-clerical':13,
       'farming-fishing':14
                                                 })

# %%
df1.insured_occupation.unique()

# %%
df1.insured_hobbies.unique()

# %%
df1.insured_hobbies=df1.insured_hobbies.map({'sleeping':1, 'reading':2, 'board-games':3, 'bungie-jumping':4,
       'base-jumping':5, 'golf':6, 'camping':7, 'dancing':8, 'skydiving':9,
       'movies':10, 'hiking':11, 'yachting':12, 'paintball':13, 'chess':14, 'kayaking':15,
       'polo':16, 'basketball':17, 'video-games':18, 'cross-fit':19, 'exercise':20})

# %%
df1.insured_hobbies.unique()

# %%
df1.insured_relationship.unique()

# %%
df1.insured_relationship=df1.insured_relationship.map({'husband':1, 'other-relative':2, 'own-child':4, 'unmarried':5, 'wife':6,'not-in-family':7})

# %%
df1.insured_relationship.unique()

# %%
df1.incident_date.unique()

# %%
df1.incident_date=pd.to_datetime(df1.incident_date)

# %%
df1['days_since_incident'] = pd.to_datetime('today') - df1.incident_date

# %%
df1.columns

# %%
df1.incident_type.unique()

# %%
df1.incident_type=df1.incident_type.map({'Single Vehicle Collision':1, 'Vehicle Theft':2,
       'Multi-vehicle Collision':3, 'Parked Car':4})

# %%
df1.incident_type.unique()

# %%
df1.collision_type.unique()

# %%
df1.collision_type=df1.collision_type.map({'Side Collision':1, 'Rear Collision':2, 'Front Collision':3})

# %%
df1.collision_type.unique()

# %%
obj

# %%
df1.incident_severity.unique()

# %%
df1.incident_severity=df1.incident_severity.map({'Major Damage':1, 'Minor Damage':2, 'Total Loss':3, 'Trivial Damage':4})

# %%
df1.incident_severity.unique()

# %%
df1.incident_state.unique()

# %%
df1.incident_state=df1.incident_state.map({'SC':1, 'VA':2, 'NY':3, 'OH':4, 'WV':5, 'NC':6, 'PA':7})

# %%
df1.incident_state.unique()

# %%
df1.incident_city.unique()

# %%
df1.incident_city=df1.incident_city.map({'Columbus':1, 'Riverwood':2, 'Arlington':3, 'Springfield':4, 'Hillsdale':5,
       'Northbend':6, 'Northbrook':7})

# %%
df1.incident_city.unique()

# %%
df1.property_damage.unique()

# %%
df1.property_damage=df1.property_damage.map({'YES':2, 'NO':1})

# %%
df1.property_damage.unique()

# %%
df1.police_report_available.unique()

# %%
df1.police_report_available=df1.police_report_available.map({'YES':2,'NO':1})

# %%
df1.police_report_available.unique()

# %%
df1.auto_make.unique()

# %%
df1.auto_make=df1.auto_make.map({'Saab':1, 'Mercedes':2, 'Dodge':3, 'Chevrolet':4, 'Accura':5, 'Nissan':6,
       'Audi':7, 'Toyota':8, 'Ford':9, 'Suburu':10, 'BMW':11, 'Jeep':11, 'Honda':12,
       'Volkswagen':13})

# %%
df1.auto_make.unique()

# %%
df1.auto_model.unique()

# %%
df1.auto_model=df1.auto_model.map({'92x':1, 'E400':2, 'RAM':3, 'Tahoe':4, 'RSX':5, '95':6, 'Pathfinder':7, 'A5':8,
       'Camry':9, 'F150':10, 'A3':11, 'Highlander':12, 'Neon':13, 'MDX':14, 'Maxima':15,
       'Legacy':16, 'TL':17, 'Impreza':18, 'Forrestor':19, 'Escape':20, 'Corolla':21,
       '3 Series':22, 'C300':23, 'Wrangler':24, 'M5':26, 'X5':27, 'Civic':28, 'Passat':29,
       'Silverado':30, 'CRV':31, '93':32, 'Accord':33, 'X6':34, 'Malibu':35, 'Fusion':36,
       'Jetta':37, 'ML350':38, 'Ultima':39, 'Grand Cherokee':40})

# %%
df1.auto_model.unique()

# %%
df1.fraud_reported.unique()

# %%
df1.fraud_reported=df1.fraud_reported.map({'Y':2,'N':1})

# %%
df1.fraud_reported.unique()

# %%
df1.columns

# %%
df1.info()

# %%
df1.policy_csl.unique()

# %%
df1.policy_csl=df1.policy_csl.map({'250/500':1, '100/300':2, '500/1000':3})

# %%
df1.policy_csl.unique()

# %%
df1.policy_state.unique()

# %%
df1.policy_state=df1.policy_state.map({'OH':1, 'IN':2, 'IL':3})

# %%
df1.policy_state.unique()

# %%
df1.insured_sex.unique()

# %%
df1.insured_sex=df1.insured_sex.map({'MALE':1, 'FEMALE':2})

# %%
df1.insured_sex.unique()

# %%
df1.authorities_contacted.unique()

# %%
df1.authorities_contacted=df1.authorities_contacted.map({'Police':1, 'None':2, 'Fire':3, 'Other':4, 'Ambulance':5})

# %%
df1.authorities_contacted.unique()

# %%
df1.policy_bind_date.unique()

# %%
df1.policy_bind_date=pd.to_datetime(df1.policy_bind_date)

# %%
df1['policy_bind_year']=df1['policy_bind_date'].dt.year

# %%
df1['policy_bind_day']=df1['policy_bind_date'].dt.day

# %%
df1['policy_bind_month']=df1['policy_bind_date'].dt.month

# %%
df1.info()

# %%
df1['incident_year']=df1['incident_date'].dt.year

# %%
df1['incident_day']=df1['incident_date'].dt.day

# %%
df1['incident_month']=df1['incident_date'].dt.month

# %%
df1.info()

# %%
df2=df1[[#'months_as_customer', 
    'age', 'policy_number', #'policy_bind_date',
       'policy_state', 'policy_csl', 'policy_deductable',
       'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
       'insured_education_level', 'insured_occupation', 'insured_hobbies',
       'insured_relationship', 'capital-gains', 'capital-loss',
       #'incident_date', 
      'incident_type', 'collision_type', 'incident_severity',
       'authorities_contacted', 'incident_state', 'incident_city',
       #'incident_location', 
        'incident_hour_of_the_day',
       'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
       'witnesses', 'police_report_available', 'total_claim_amount',
       'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
       'auto_model', 'auto_year', 'fraud_reported', #'days_since_incident',
       'policy_bind_year', 'policy_bind_day', 'policy_bind_month',
       'incident_year', 'incident_day', 'incident_month']]

# %% [markdown]
# # Z-score to locate the outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df2))
z

# %%
threshold=3
print(np.where(z>3))

# %%
df3=df2[((z<3).all (axis=1))]

# %%
df3.shape

# %% [markdown]
# # To check MultiColinearity

# %%
df2_cor=df2.corr()
plt.figure(figsize=(30,14))
sns.heatmap(df2_cor,annot=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x1=df2.drop(['fraud_reported'],axis=1)

# %%
y1=df2['fraud_reported']

# %%
x1.columns

# %%
x1=x1[['policy_state', 'policy_deductable', 'policy_annual_premium',
       'umbrella_limit', #'insured_zip', 
       'insured_sex', #'insured_relationship',
       'capital-gains', 'capital-loss', #'incident_date', 'incident_type',
       'collision_type', 'incident_severity', 'authorities_contacted',
       'incident_state', 'incident_city', #'incident_location',
       'incident_hour_of_the_day', 'number_of_vehicles_involved',
       'property_damage', 'bodily_injuries', 'witnesses',
       'police_report_available', 'total_claim_amount', 'injury_claim',
       'property_claim', 'vehicle_claim', 'auto_make', 'auto_model',
       'auto_year', #'days_since_incident', 
       'policy_bind_year',
       'policy_bind_day', 'policy_bind_month', 'incident_year', 'incident_day',
       'incident_month']]

# %%
from imblearn.over_sampling import SMOTE
smt1=SMOTE()
x1_sampled,y1_sampled=smt1.fit_resample(x1,y1)

# %%
y1_sampled.value_counts()
# Out:
# 2    753
# 1    753
# Name: fraud_reported, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import train_test_split,cross_val_score

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
maxAcc=0
maxRs=0
for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x1_sampled,y1_sampled,test_size=.20,random_state=i)
    rf1=RandomForestClassifier()
    rf1.fit(x_train,y_train)
    pred=rf1.predict(x_test)
    accuracy=accuracy_score(y_test,pred)
    if accuracy>maxAcc:
        maxAcc=accuracy
        maxRs=i
print(f'Best Accuracy for the sampled date is {maxAcc} and randomstate is{maxRs}')
# Out:
# Best Accuracy for the sampled date is 0.9139072847682119 and randomstate is15

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
maxAcc=0
maxRs=0
for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x1_sampled,y1_sampled,test_size=.20,random_state=i)
    et=ExtraTreesClassifier()
    et.fit(x_train,y_train)
    pred=et.predict(x_test)
    accuracy=accuracy_score(y_test,pred)
    if accuracy>maxAcc:
        maxAcc=accuracy
        maxRs=i
print(f'Best Accuracy for the sampled date is {maxAcc} and randomstate is{maxRs}')
# Out:
# Best Accuracy for the sampled date is 0.9072847682119205 and randomstate is15

# %%
def modelcheck(models,x,y):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x,y,test_size=.30,random_state=rs)
        
    for model in models:
          
            print(f'Model:{model.__class__.__name__} with random_state={rs}')
            model.fit(x1_train,y1_train)
            pred_model=model.predict(x1_test)
            accuracy=accuracy_score(y1_test,pred_model)
            print(f'Accuracy:{accuracy}')
            print('Confusion_matrix:',confusion_matrix(y1_test,pred_model))
            print('Classification_report:',classification_report(y1_test,pred_model))
            model_cross_score=cross_val_score(model,x,y,cv=5)
            print(model_cross_score)
            print(model_cross_score.mean())
        
            difference= accuracy-model_cross_score.mean()
            print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
        
rf1=RandomForestClassifier()
dtc1=DecisionTreeClassifier()
knn1=KNeighborsClassifier()
et1=ExtraTreesClassifier()
ada1=AdaBoostClassifier(algorithm='SAMME')
gb1=GradientBoostingClassifier()
x=x1_sampled
y=y1_sampled
rs=15
models=[rf1,dtc1,knn1,et1,ada1,gb1]
modelcheck(models,x,y)
# Out:
# Model:RandomForestClassifier with random_state=15
# Accuracy:0.8960176991150443
# Confusion_matrix: [[196  21]
#  [ 26 209]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       0.88      0.90      0.89       217
#            2       0.91      0.89      0.90       235
#
#     accuracy                           0.90       452
#    macro avg       0.90      0.90      0.90       452
# weighted avg       0.90      0.90      0.90       452
#
# [0.72847682 0.80066445 0.90697674 0.90697674 0.92358804]
# 0.8533365602516996
# Difference Between Accuracy and Cross_val_score mean: 0.04268113886334468
#
# Model:DecisionTreeClassifier with random_state=15
# Accuracy:0.7610619469026548
# Confusion_matrix: [[155  62]
#  [ 46 189]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       0.77      0.71      0.74       217
#            2       0.75      0.80      0.78       235
#
# ...

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1_sampled,y1_sampled,test_size=.20,random_state=15)

# %%
rf1=RandomForestClassifier()
rf1.fit(x1_train,y1_train)
# Out:
# RandomForestClassifier()

# %%
rf1_pred=rf1.predict(x1_test)

# %%
accuracy=accuracy_score(y1_test,rf1_pred)
print(f'Accuracy:{accuracy}')
print('Confusion_matrix:',confusion_matrix(y1_test,rf1_pred))
print('Classification_report:',classification_report(y1_test,rf1_pred))
rf1_cross_score=cross_val_score(rf1,x,y,cv=5)
print(rf1_cross_score)
print(rf1_cross_score.mean())
difference= accuracy-rf1_cross_score.mean()
print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
# Out:
# Accuracy:0.9039735099337748
# Confusion_matrix: [[133  14]
#  [ 15 140]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       0.90      0.90      0.90       147
#            2       0.91      0.90      0.91       155
#
#     accuracy                           0.90       302
#    macro avg       0.90      0.90      0.90       302
# weighted avg       0.90      0.90      0.90       302
#
# [0.72516556 0.80730897 0.89700997 0.90365449 0.92358804]
# 0.8513454049415856
# Difference Between Accuracy and Cross_val_score mean: 0.05262810499218917

# %%
et1=ExtraTreesClassifier()
et1.fit(x1_train,y1_train)
# Out:
# ExtraTreesClassifier()

# %%
et1_pred=et1.predict(x1_test)

# %%
accuracy=accuracy_score(y1_test,et1_pred)
print(f'Accuracy:{accuracy}')
print('Confusion_matrix:',confusion_matrix(y1_test,et1_pred))
print('Classification_report:',classification_report(y1_test,et1_pred))
et1_cross_score=cross_val_score(et1,x,y,cv=5)
print(et1_cross_score)
print(et1_cross_score.mean())
difference= accuracy-et1_cross_score.mean()
print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
# Out:
# Accuracy:0.9105960264900662
# Confusion_matrix: [[132  15]
#  [ 12 143]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       0.92      0.90      0.91       147
#            2       0.91      0.92      0.91       155
#
#     accuracy                           0.91       302
#    macro avg       0.91      0.91      0.91       302
# weighted avg       0.91      0.91      0.91       302
#
# [0.69536424 0.79069767 0.89368771 0.89700997 0.93687708]
# 0.8427273327319529
# Difference Between Accuracy and Cross_val_score mean: 0.06786869375811333

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# Initialize GridSearchCV with the ExtraTreesRegressor and parameter grid
grid_search_etr = GridSearchCV(estimator=et1, param_grid=param_grid, cv=5, n_jobs=-1, scoring='neg_mean_squared_error')

# Fit GridSearchCV to the training data
grid_search_etr.fit(x1_train, y1_train)

# Get the best parameters and best score
best_params_etr = grid_search_etr.best_params_
best_score_etr = grid_search_etr.best_score_

print("Best Parameters for ExtraTreesRegressor:", best_params_etr)
print("Best Score for ExtraTreesRegressor:", best_score_etr)
# Out:
# C:\Users\ganes\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 540 fits failed out of a total of 1620.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 540 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ganes\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ganes\anaconda3\lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ganes\anaconda3\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
eth1=ExtraTreesClassifier(max_depth= None, max_features= 'log2', min_samples_leaf= 1, min_samples_split= 2, n_estimators= 200)
eth1.fit(x1_train,y1_train)
# Out:
# ExtraTreesClassifier(max_features='log2', n_estimators=200)

# %%
eth1_pred=eth1.predict(x1_test)

# %%
accuracy=accuracy_score(y1_test,eth1_pred)
print(f'Accuracy:{accuracy}')
print('Confusion_matrix:',confusion_matrix(y1_test,eth1_pred))
print('Classification_report:',classification_report(y1_test,eth1_pred))
eth1_cross_score=cross_val_score(eth1,x,y,cv=5)
print(eth1_cross_score)
print(eth1_cross_score.mean())
difference= accuracy-eth1_cross_score.mean()
print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
# Out:
# Accuracy:0.9105960264900662
# Confusion_matrix: [[133  14]
#  [ 13 142]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       0.91      0.90      0.91       147
#            2       0.91      0.92      0.91       155
#
#     accuracy                           0.91       302
#    macro avg       0.91      0.91      0.91       302
# weighted avg       0.91      0.91      0.91       302
#
# [0.70529801 0.81063123 0.910299   0.91694352 0.93355482]
# 0.8553453169347209
# Difference Between Accuracy and Cross_val_score mean: 0.05525070955534528

# %%
import joblib

# %%
joblib.dump(et1,'auto_insurance_fraud_analysis.pkl')
# Out:
# ['auto_insurance_fraud_analysis.pkl']

# %%
model=joblib.load('auto_insurance_fraud_analysis.pkl')
prediction=model.predict(x1_test)

# %%
a=np.array(y1_test)
df_test=pd.DataFrame()
df_test['original']=a
df_test['Prediction']=prediction
df_test
# Out:
#      original  Prediction
# 0           2           2
# 1           2           2
# 2           1           1
# 3           2           2
# 4           2           2
# ..        ...         ...
# 297         2           2
# 298         1           1
# 299         1           1
# 300         1           1
# 301         2           2
#
# [302 rows x 2 columns]
