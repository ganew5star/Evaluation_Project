# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
# Out:
# C:\Users\ganes\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dx=pd.read_csv('loan_prediction.csv')
dx
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df=pd.DataFrame(dx)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Feature's characteristics of the dataset
# 1.	Loan_ID - This refer to the unique identifier of the applicant's affirmed purchases
# 2.	Gender - This refers to either of the two main categories (male and female) into which applicants are divided on the basis of their reproductive functions
# 3.	Married - This refers to applicant being in a state of matrimony
# 4.	Dependents - This refres to persons who depends on the applicants for survival
# 5.	Education - This refers to number of years in which applicant received systematic instruction, especially at a school or university
# 6.	Self_Employed - This refers to applicant working for oneself as a freelancer or the owner of a business rather than for an employer
# 7.	Applicant Income - This refers to disposable income available for the applicant's use under State law.
# 8.	CoapplicantIncome - This refers to disposable income available for the people that participate in the loan application process alongside the main applicant use under State law.
# 9.	Loan_Amount - This refers to the amount of money an applicant owe at any given time.
# 10.	Loan_Amount_Term - This refers to the duaration in which the loan is availed to the applicant
# 11.	Credit History - This refers to a record of applicant's ability to repay debts and demonstrated responsibility in repaying them.
# 12.	Property_Area - This refers to the total area within the boundaries of the property as set out in Schedule.
# 13.	Loan_Status - This refers to whether applicant is eligible to be availed the Loan requested.

# %%
df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# # Observation:
#     According to above status of the dataset:
#         1.Dataset has 614 rows and 13 characteristics features (feature characteristics explained above in detailed.)
#         2.It has 8 object datatypes and 5 numeric datatypes.
#         3.Null values present in Gender,Married,Dependents,Self-Employed,LoanAmount,Loan_Amount_Term and Credit_History respectively.

# %% [markdown]
# # To replace nullValues:

# %%
df['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
mode_gender=df['Gender'].mode()[0]
df['Gender']=df['Gender'].fillna(mode_gender)

# %%
df['Gender'].isnull().sum()
# Out:
# 0

# %%
df['Married'].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
mode_married=df['Married'].mode()[0]
df['Married']=df['Married'].fillna(mode_married)

# %%
df['Married'].isnull().sum()
# Out:
# 0

# %%
df['Dependents'].value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
mode_dependent=df['Dependents'].mode()[0]
df['Dependents']=df['Dependents'].fillna(mode_dependent)

# %%
df['Dependents'].isnull().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df['Self_Employed'].value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
mode_self_employed=df['Self_Employed'].mode()[0]
df['Self_Employed']=df['Self_Employed'].fillna(mode_self_employed)

# %%
df['Self_Employed'].isnull().sum()
# Out:
# 0

# %%
df['LoanAmount'].value_counts()
# Out:
# 120.0    20
# 110.0    17
# 100.0    15
# 160.0    12
# 187.0    12
#          ..
# 240.0     1
# 214.0     1
# 59.0      1
# 166.0     1
# 253.0     1
# Name: LoanAmount, Length: 203, dtype: int64

# %%
mean_loanamount=df['LoanAmount'].mean()
df['LoanAmount']=df['LoanAmount'].fillna(mean_loanamount)

# %%
df['LoanAmount'].isnull().sum()
# Out:
# 0

# %%
df['Loan_Amount_Term'].value_counts()
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
mean_Loan_Amount_Term = df['Loan_Amount_Term'].mean()
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(mean_Loan_Amount_Term)

# %%
df['Loan_Amount_Term'].isnull().sum()
# Out:
# 0

# %%
df['Credit_History'].value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
mode_Credit_History=df['Credit_History'].mode()[0]
df['Credit_History']=df['Credit_History'].fillna(mode_Credit_History)

# %%
df['Credit_History'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df['TotalIncome'] = df['ApplicantIncome'] + df['CoapplicantIncome']
df['Income_to_Loan_Ratio'] = df['TotalIncome'] / df['LoanAmount']

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'TotalIncome', 'Income_to_Loan_Ratio'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Loan_ID               614 non-null    object
#  1   Gender                614 non-null    object
#  2   Married               614 non-null    object
#  3   Dependents            614 non-null    object
#  4   Education             614 non-null    object
#  5   Self_Employed         614 non-null    object
#  6   ApplicantIncome       614 non-null    int64
#  7   CoapplicantIncome     614 non-null    float64
#  8   LoanAmount            614 non-null    float64
#  9   Loan_Amount_Term      614 non-null    float64
#  10  Credit_History        614 non-null    float64
#  11  Property_Area         614 non-null    object
#  12  Loan_Status           614 non-null    object
#  13  TotalIncome           614 non-null    float64
#  14  Income_to_Loan_Ratio  614 non-null    float64
# ...

# %% [markdown]
# # EDA:

# %% [markdown]
# # Univariate:

# %%
obj=[]
for i in df.columns:
    if df[i].dtype==object:
        obj.append(i)
print(obj)
# Out:
# ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']

# %%
num=[]
for j in df.columns:
    if df[j].dtype!=object:
        num.append(j)
print(num)
# Out:
# ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'TotalIncome', 'Income_to_Loan_Ratio']

# %% [markdown]
# # Numerical representation:

# %%
for i in num:
    plt.figure(figsize=(10,6))
    sns.histplot(x=df[i],kde=True)
    plt.show()

# %%
for i in num:
    plt.figure(figsize=(10,4))
    sns.boxplot(x=df[i])
    plt.title(f'Box plot of {i}')

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.412162        342.000000
# std        6109.041673        2926.248369   84.037468         64.372489
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  129.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History   TotalIncome  Income_to_Loan_Ratio
# count      614.000000    614.000000            614.000000
# mean         0.855049   7024.705081             50.963070
# std          0.352339   6458.663872             37.621359
# min          0.000000   1442.000000             12.090196
# ...

# %% [markdown]
# # Observation:
#     1.DataSet widely spreaded in ApplicantIncome,CoApplicantIncome and TotalIncome
#     2.Skewness present in the all the features
#     3.Outlier are present in the dataset as shown in the boxplot

# %% [markdown]
# # Categorical Representation:

# %%
for i in obj:
    plt.figure(figsize=(10,4))
    sns.countplot(x=df[i])
    plt.title(f'Count of feature {i}')

# %%
plt.figure(figsize=(10,4))
sns.countplot(x=df['Credit_History'])
plt.title(f'Count of credit History')
# Out:
# Text(0.5, 1.0, 'Count of credit History')

# %% [markdown]
# # Observation:
#     According the count plot for categorical values present in the dataset:
#         1.Male applicant is more compared with female applicant
#         2.Married applicant is more in the dataset and 0 dependent is more in the dataset too.
#         3.Credit_history say more number of applicant has the history.

# %% [markdown]
# # BiVariate:

# %% [markdown]
# # Numerical representation:

# %%
for i in num:
    plt.figure(figsize=(10,4))
    sns.swarmplot(x=df['Loan_Status'],y=df[i])
    plt.title(f'Comparison plot of Loan_Status vs {i}')
# Out:
# C:\Users\ganes\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ganes\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 22.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ganes\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 51.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ganes\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 28.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
for i in num:
    plt.figure(figsize=(10,4))
    sns.stripplot(x=df['Loan_Status'],y=df[i])
    plt.title(f'Comparison plot of Loan_Status vs {i}')

# %% [markdown]
# # Observation:
#     According to numerical features in the comparison with target variable Loan_Status:
#         1.Dataset has huge datapoints combined in the flow for the features.

# %% [markdown]
# # Categorical Representation:

# %%
for i in obj:
    plt.figure(figsize=(10,4))
    sns.countplot(hue=df['Loan_Status'],x=df[i])
    plt.title(f'Comparison plot of Loan_Status vs {i}')

# %%
plt.figure(figsize=(10,4))
sns.countplot(hue=df['Loan_Status'],x=df['Credit_History'])
plt.title(f'Comparison plot of Loan_Status vs Credit_History')
# Out:
# Text(0.5, 1.0, 'Comparison plot of Loan_Status vs Credit_History')

# %% [markdown]
# # Observation:
#     The Loan status got sanctioned for the below explanation:
#         1.Graduate is must, No Self_Employed,Property in Semiurban area,No Dependent and Male applicant.

# %% [markdown]
# # Multivariate:

# %%
sns.pairplot(df,hue='Loan_Status')

# %% [markdown]
# # Observation:
#     Here the overall comparison of the dataset with respect to the target variable(Loan_Status):
#         Total Income is pretty good in regressive type to get possibilities of Loan Sanctioning.
#         Income_to_Loan_Ration is quite good to predict the loan_status.

# %% [markdown]
# # Labelling the objective type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Loan_ID               614 non-null    object
#  1   Gender                614 non-null    object
#  2   Married               614 non-null    object
#  3   Dependents            614 non-null    object
#  4   Education             614 non-null    object
#  5   Self_Employed         614 non-null    object
#  6   ApplicantIncome       614 non-null    int64
#  7   CoapplicantIncome     614 non-null    float64
#  8   LoanAmount            614 non-null    float64
#  9   Loan_Amount_Term      614 non-null    float64
#  10  Credit_History        614 non-null    float64
#  11  Property_Area         614 non-null    object
#  12  Loan_Status           614 non-null    object
#  13  TotalIncome           614 non-null    float64
#  14  Income_to_Loan_Ratio  614 non-null    float64
# ...

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender']=df['Gender'].map({'Male':1, 'Female':2})

# %%
df['Gender'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
df['Married'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Married']=df['Married'].map({'No':1, 'Yes':2})

# %%
df['Married'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+'], dtype=object)

# %%
df['Dependents']=df['Dependents'].map({'0':1, '1':2, '2':3, '3+':4})

# %%
df['Dependents'].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
df['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df['Education']=df['Education'].map({'Graduate':1, 'Not Graduate':2})

# %%
df['Education'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
df['Self_Employed'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Self_Employed']=df['Self_Employed'].map({'No':1, 'Yes':2})

# %%
df['Self_Employed'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
df['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
df['Property_Area']=df['Property_Area'].map({'Urban':1, 'Rural':2, 'Semiurban':3})

# %%
df['Property_Area'].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df['Loan_Status'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df['Loan_Status']=df['Loan_Status'].map({'Y':1, 'N':2})

# %%
df['Loan_Status'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Loan_ID               614 non-null    object
#  1   Gender                614 non-null    int64
#  2   Married               614 non-null    int64
#  3   Dependents            614 non-null    int64
#  4   Education             614 non-null    int64
#  5   Self_Employed         614 non-null    int64
#  6   ApplicantIncome       614 non-null    int64
#  7   CoapplicantIncome     614 non-null    float64
#  8   LoanAmount            614 non-null    float64
#  9   Loan_Amount_Term      614 non-null    float64
#  10  Credit_History        614 non-null    float64
#  11  Property_Area         614 non-null    int64
#  12  Loan_Status           614 non-null    int64
#  13  TotalIncome           614 non-null    float64
#  14  Income_to_Loan_Ratio  614 non-null    float64
# ...

# %%
df['Loan_Amount_Term']=df['Loan_Amount_Term'].astype(int)

# %%
df['Credit_History']=df['Credit_History'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Loan_ID               614 non-null    object
#  1   Gender                614 non-null    int64
#  2   Married               614 non-null    int64
#  3   Dependents            614 non-null    int64
#  4   Education             614 non-null    int64
#  5   Self_Employed         614 non-null    int64
#  6   ApplicantIncome       614 non-null    int64
#  7   CoapplicantIncome     614 non-null    float64
#  8   LoanAmount            614 non-null    float64
#  9   Loan_Amount_Term      614 non-null    int32
#  10  Credit_History        614 non-null    int32
#  11  Property_Area         614 non-null    int64
#  12  Loan_Status           614 non-null    int64
#  13  TotalIncome           614 non-null    float64
#  14  Income_to_Loan_Ratio  614 non-null    float64
# ...

# %% [markdown]
# # Scenario:1 Removing Outliers

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'TotalIncome', 'Income_to_Loan_Ratio'],
#       dtype='object')

# %%
df1=df[[#'Loan_ID', 
    'Gender', 'Married', 'Dependents', 'Education',
       'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
       'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
       'TotalIncome', 'Income_to_Loan_Ratio']]

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df1))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  9,  14,  68,  94, 126, 130, 133, 146, 155, 155, 155, 171, 171,
#        171, 177, 177, 183, 183, 185, 185, 185, 242, 262, 278, 308, 313,
#        333, 333, 333, 369, 370, 402, 402, 409, 409, 409, 417, 432, 443,
#        443, 443, 478, 487, 495, 497, 506, 506, 509, 523, 525, 546, 555,
#        561, 568, 575, 581, 581, 581, 585, 600, 600, 604], dtype=int64), array([ 6,  8,  8,  8,  5,  7,  8, 13,  5,  7, 12,  5,  7, 12,  6,  7,  5,
#        12,  5, 12, 13,  8,  8,  7,  7,  8,  5,  7, 12,  7, 13,  6, 13,  5,
#        12, 13,  6,  7,  5, 12, 13, 13,  7,  8,  8,  7, 12, 13,  7,  7,  8,
#        13,  7, 13,  8,  6, 12, 13,  8,  6, 12,  7], dtype=int64))

# %%
df2=df1[((z<3).all (axis=1))]

# %%
df2.shape
# Out:
# (571, 14)

# %% [markdown]
# # Checking for MultiCollinearity after removed of outliers

# %%
df2_cor=df2.corr()
plt.figure(figsize=(20,14))
sns.heatmap(df2_cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x1=df2.drop(['Loan_Status'],axis=1)

# %%
y1=df2['Loan_Status']

# %%
def vifcheck(x1):
    vif=pd.DataFrame()
    vif['Original']=x1.columns
    vif['Variance_inflation_factor']=[variance_inflation_factor(x1.values,i) for i in range(x1.shape[1])]
    print(vif)

# %%
vifcheck(x1)
# Out:
#                 Original  Variance_inflation_factor
# 0                 Gender                  10.942209
# 1                Married                  15.266017
# 2             Dependents                   4.652447
# 3              Education                   8.916168
# 4          Self_Employed                  12.705224
# 5        ApplicantIncome                        inf
# 6      CoapplicantIncome                        inf
# 7             LoanAmount                  43.489397
# 8       Loan_Amount_Term                  31.555435
# 9         Credit_History                   6.621006
# 10         Property_Area                   7.143250
# 11           TotalIncome                        inf
# 12  Income_to_Loan_Ratio                  28.464342
# C:\Users\ganes\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:195: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)

# %%
x1.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'TotalIncome',
#        'Income_to_Loan_Ratio'],
#       dtype='object')

# %%
x1=x1[['Gender', 'Married', 
       'Dependents', 'Education', 'Self_Employed',
       'ApplicantIncome', 'CoapplicantIncome', 
        'LoanAmount',
       'Loan_Amount_Term', 
       'Credit_History', 'Property_Area', #'TotalIncome',
       #'Income_to_Loan_Ratio'
      ]]

# %%
vifcheck(x1)
# Out:
#              Original  Variance_inflation_factor
# 0              Gender                  10.432968
# 1             Married                  14.225190
# 2          Dependents                   4.644553
# 3           Education                   8.721723
# 4       Self_Employed                  12.380258
# 5     ApplicantIncome                   6.367579
# 6   CoapplicantIncome                   2.587333
# 7          LoanAmount                  13.122110
# 8    Loan_Amount_Term                  28.565660
# 9      Credit_History                   6.405115
# 10      Property_Area                   7.136062

# %%
from sklearn.preprocessing import StandardScaler

# %%
std1=StandardScaler()
x1_scaled=pd.DataFrame(std1.fit_transform(x1),columns=x1.columns)

# %%
from imblearn.over_sampling import SMOTE
smt1=SMOTE()
x1_sampled,y1_sampled=smt1.fit_resample(x1_scaled,y1)

# %%
y1_sampled.value_counts()
# Out:
# 1    393
# 2    393
# Name: Loan_Status, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import train_test_split,cross_val_score

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
maxAcc=0
maxRs=0
for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x1_sampled,y1_sampled,test_size=.30,random_state=i)
    knn1=KNeighborsClassifier()
    knn1.fit(x_train,y_train)
    pred=knn1.predict(x_test)
    accuracy=accuracy_score(y_test,pred)
    if accuracy>maxAcc:
        maxAcc=accuracy
        maxRs=i
print(f'Best Accuracy for the sampled date is {maxAcc} and randomstate is{maxRs}')
# Out:
# Best Accuracy for the sampled date is 0.8220338983050848 and randomstate is5

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
maxAcc=0
maxRs=0
for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x1_sampled,y1_sampled,test_size=.30,random_state=i)
    rf=RandomForestClassifier()
    rf.fit(x_train,y_train)
    pred=rf.predict(x_test)
    accuracy=accuracy_score(y_test,pred)
    if accuracy>maxAcc:
        maxAcc=accuracy
        maxRs=i
print(f'Best Accuracy for the sampled date is {maxAcc} and randomstate is{maxRs}')
# Out:
# Best Accuracy for the sampled date is 0.885593220338983 and randomstate is95

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
maxAcc=0
maxRs=0
for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x1_sampled,y1_sampled,test_size=.30,random_state=i)
    et=ExtraTreesClassifier()
    et.fit(x_train,y_train)
    pred=et.predict(x_test)
    accuracy=accuracy_score(y_test,pred)
    if accuracy>maxAcc:
        maxAcc=accuracy
        maxRs=i
print(f'Best Accuracy for the sampled date is {maxAcc} and randomstate is{maxRs}')
# Out:
# Best Accuracy for the sampled date is 0.885593220338983 and randomstate is141

# %%
def modelcheck(models,x,y):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x,y,test_size=.30,random_state=rs)
        
    for model in models:
          
            print(f'Model:{model.__class__.__name__} with random_state={rs}')
            model.fit(x1_train,y1_train)
            pred_model=model.predict(x1_test)
            accuracy=accuracy_score(y1_test,pred_model)
            print(f'Accuracy:{accuracy}')
            print('Confusion_matrix:',confusion_matrix(y1_test,pred_model))
            print('Classification_report:',classification_report(y1_test,pred_model))
            model_cross_score=cross_val_score(model,x,y,cv=5)
            print(model_cross_score)
            print(model_cross_score.mean())
        
            difference= accuracy-model_cross_score.mean()
            print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
        
rf1=RandomForestClassifier()
dtc1=DecisionTreeClassifier()
knn1=KNeighborsClassifier()
et1=ExtraTreesClassifier()
ada1=AdaBoostClassifier(algorithm='SAMME')
gb1=GradientBoostingClassifier()
x=x1_sampled
y=y1_sampled
rs=141
models=[rf1,dtc1,knn1,et1,ada1,gb1]
modelcheck(models,x,y)
# Out:
# Model:RandomForestClassifier with random_state=141
# Accuracy:0.864406779661017
# Confusion_matrix: [[ 96  11]
#  [ 21 108]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       0.82      0.90      0.86       107
#            2       0.91      0.84      0.87       129
#
#     accuracy                           0.86       236
#    macro avg       0.86      0.87      0.86       236
# weighted avg       0.87      0.86      0.86       236
#
# [0.77848101 0.78343949 0.88535032 0.87898089 0.88535032]
# 0.8423204063533017
# Difference Between Accuracy and Cross_val_score mean: 0.022086373307715235
#
# Model:DecisionTreeClassifier with random_state=141
# Accuracy:0.7838983050847458
# Confusion_matrix: [[ 80  27]
#  [ 24 105]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       0.77      0.75      0.76       107
#            2       0.80      0.81      0.80       129
#
# ...

# %% [markdown]
# # Scenario:2 Without removing outliers

# %%
x2=df1.drop(['Loan_Status'],axis=1)

# %%
y2=df1['Loan_Status']

# %%
std2=StandardScaler()
x2_scaled=pd.DataFrame(std2.fit_transform(x2),columns=x2.columns)

# %%
def vifcheck(x2_scaled):
    vif=pd.DataFrame()
    vif['Original']=x2_scaled.columns
    vif['Variance_inflation_factor']=[variance_inflation_factor(x2_scaled.values,i) for i in range(x2_scaled.shape[1])]
    print(vif)

# %%
vifcheck(x2_scaled)
# Out:
#                 Original  Variance_inflation_factor
# 0                 Gender                   1.178813
# 1                Married                   1.283286
# 2             Dependents                   1.165781
# 3              Education                   1.064720
# 4          Self_Employed                   1.042460
# 5        ApplicantIncome                        inf
# 6      CoapplicantIncome                        inf
# 7             LoanAmount                   3.243635
# 8       Loan_Amount_Term                   1.050693
# 9         Credit_History                   1.018472
# 10         Property_Area                   1.018524
# 11           TotalIncome                        inf
# 12  Income_to_Loan_Ratio                   2.739204
# C:\Users\ganes\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:195: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)

# %%
x2_scaled.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'TotalIncome',
#        'Income_to_Loan_Ratio'],
#       dtype='object')

# %%
x2_scaled=x2_scaled[['Gender', 'Married', 
                     'Dependents', 'Education', 'Self_Employed',
       'ApplicantIncome', 'CoapplicantIncome', 
                     'LoanAmount',
       'Loan_Amount_Term', 'Credit_History', 'Property_Area', #'TotalIncome',
       #'Income_to_Loan_Ratio'
                    ]]

# %%
smt2=SMOTE()
x2_sampled,y2_sampled=smt2.fit_resample(x2_scaled,y2)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
maxAcc=0
maxRs=0
for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x2_sampled,y2_sampled,test_size=.30,random_state=i)
    knn1=KNeighborsClassifier()
    knn1.fit(x_train,y_train)
    pred=knn1.predict(x_test)
    accuracy=accuracy_score(y_test,pred)
    if accuracy>maxAcc:
        maxAcc=accuracy
        maxRs=i
print(f'Best Accuracy for the sampled date is {maxAcc} and randomstate is{maxRs}')
# Out:
# Best Accuracy for the sampled date is 0.7834645669291339 and randomstate is95

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
maxAcc=0
maxRs=0
for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x2_sampled,y2_sampled,test_size=.30,random_state=i)
    rf=RandomForestClassifier()
    rf.fit(x_train,y_train)
    pred=rf.predict(x_test)
    accuracy=accuracy_score(y_test,pred)
    if accuracy>maxAcc:
        maxAcc=accuracy
        maxRs=i
print(f'Best Accuracy for the sampled date is {maxAcc} and randomstate is{maxRs}')
# Out:
# Best Accuracy for the sampled date is 0.8622047244094488 and randomstate is106

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
maxAcc=0
maxRs=0
for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x2_sampled,y2_sampled,test_size=.30,random_state=i)
    et=ExtraTreesClassifier()
    et.fit(x_train,y_train)
    pred=et.predict(x_test)
    accuracy=accuracy_score(y_test,pred)
    if accuracy>maxAcc:
        maxAcc=accuracy
        maxRs=i
print(f'Best Accuracy for the sampled date is {maxAcc} and randomstate is{maxRs}')
# Out:
# Best Accuracy for the sampled date is 0.8779527559055118 and randomstate is106

# %%
def modelcheck(models,x,y):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x,y,test_size=.30,random_state=rs)
        
    for model in models:
          
            print(f'Model:{model.__class__.__name__} with random_state={rs}')
            model.fit(x1_train,y1_train)
            pred_model=model.predict(x1_test)
            accuracy=accuracy_score(y1_test,pred_model)
            print(f'Accuracy:{accuracy}')
            print('Confusion_matrix:',confusion_matrix(y1_test,pred_model))
            print('Classification_report:',classification_report(y1_test,pred_model))
            model_cross_score=cross_val_score(model,x,y,cv=5)
            print(model_cross_score)
            print(model_cross_score.mean())
        
            difference= accuracy-model_cross_score.mean()
            print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
        
rf2=RandomForestClassifier()
dtc2=DecisionTreeClassifier()
knn2=KNeighborsClassifier()
et2=ExtraTreesClassifier()
ada2=AdaBoostClassifier(algorithm='SAMME')
gb2=GradientBoostingClassifier()
x=x2_sampled
y=y2_sampled
rs=106
models=[rf2,dtc2,knn2,et2,ada2,gb2]
modelcheck(models,x,y)
# Out:
# Model:RandomForestClassifier with random_state=106
# Accuracy:0.8818897637795275
# Confusion_matrix: [[124  13]
#  [ 17 100]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       0.88      0.91      0.89       137
#            2       0.88      0.85      0.87       117
#
#     accuracy                           0.88       254
#    macro avg       0.88      0.88      0.88       254
# weighted avg       0.88      0.88      0.88       254
#
# [0.74556213 0.79289941 0.83431953 0.86982249 0.88095238]
# 0.8247111862496478
# Difference Between Accuracy and Cross_val_score mean: 0.05717857752987976
#
# Model:DecisionTreeClassifier with random_state=106
# Accuracy:0.7992125984251969
# Confusion_matrix: [[107  30]
#  [ 21  96]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       0.84      0.78      0.81       137
#            2       0.76      0.82      0.79       117
#
# ...

# %%
x2_train,x2_test,y2_train,y2_test=train_test_split(x2_sampled,y2_sampled,test_size=.30,random_state=106)

# %%
rf2=RandomForestClassifier()
rf2.fit(x2_train,y2_train)
# Out:
# RandomForestClassifier()

# %%
rf2_pred=rf2.predict(x2_test)

# %%
accuracy=accuracy_score(y2_test,rf2_pred)
print(f'Accuracy:{accuracy}')
print('Confusion_matrix:',confusion_matrix(y2_test,rf2_pred))
print('Classification_report:',classification_report(y2_test,rf2_pred))
rf2_cross_score=cross_val_score(rf2,x,y,cv=5)
print(rf2_cross_score)
print(rf2_cross_score.mean())
difference= accuracy-rf2_cross_score.mean()
print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
# Out:
# Accuracy:0.8818897637795275
# Confusion_matrix: [[124  13]
#  [ 17 100]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       0.88      0.91      0.89       137
#            2       0.88      0.85      0.87       117
#
#     accuracy                           0.88       254
#    macro avg       0.88      0.88      0.88       254
# weighted avg       0.88      0.88      0.88       254
#
# [0.74556213 0.76923077 0.84615385 0.86982249 0.875     ]
# 0.8211538461538461
# Difference Between Accuracy and Cross_val_score mean: 0.060735917625681424

# %%
rfh2=RandomForestClassifier(n_estimators= 200, max_depth= 30, min_samples_split= 2, min_samples_leaf= 1)
rfh2.fit(x2_train,y2_train)
# Out:
# RandomForestClassifier(max_depth=30, n_estimators=200)

# %%
rfh2_pred=rfh2.predict(x2_test)

# %%
accuracy=accuracy_score(y2_test,rfh2_pred)
print(f'Accuracy:{accuracy}')
print('Confusion_matrix:',confusion_matrix(y2_test,rfh2_pred))
print('Classification_report:',classification_report(y2_test,rfh2_pred))
rfh2_cross_score=cross_val_score(rfh2,x,y,cv=5)
print(rfh2_cross_score)
print(rfh2_cross_score.mean())
difference= accuracy-rfh2_cross_score.mean()
print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
# Out:
# Accuracy:0.8779527559055118
# Confusion_matrix: [[122  15]
#  [ 16 101]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       0.88      0.89      0.89       137
#            2       0.87      0.86      0.87       117
#
#     accuracy                           0.88       254
#    macro avg       0.88      0.88      0.88       254
# weighted avg       0.88      0.88      0.88       254
#
# [0.74556213 0.76331361 0.85207101 0.85207101 0.875     ]
# 0.8176035502958581
# Difference Between Accuracy and Cross_val_score mean: 0.06034920560965373

# %%
import joblib

# %%
joblib.dump(rf2,'Bank_loan_prediction_analysis.pkl')
# Out:
# ['Bank_loan_prediction_analysis.pkl']

# %%
model=joblib.load('Bank_loan_prediction_analysis.pkl')
prediction=model.predict(x2_test)

# %%
a=np.array(y2_test)
df_test=pd.DataFrame()
df_test['original']=a
df_test['Prediction']=prediction
df_test
# Out:
#      original  Prediction
# 0           1           1
# 1           2           2
# 2           1           1
# 3           1           1
# 4           1           1
# ..        ...         ...
# 249         2           2
# 250         2           2
# 251         2           2
# 252         1           1
# 253         1           1
#
# [254 rows x 2 columns]
