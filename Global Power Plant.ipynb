# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# C:\Users\ganes\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dx=pd.read_csv('global_Power_plant_database.csv')
dx
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 903     IND        India                  YERMARUS TPP  IND0000513
# 904     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 905     IND        India  Yelisirur wind power project  WRI1026776
# 906     IND        India                   ZAWAR MINES  WRI1019901
# 907     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
df=pd.DataFrame(dx)

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 903     IND        India                  YERMARUS TPP  IND0000513
# 904     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 905     IND        India  Yelisirur wind power project  WRI1026776
# 906     IND        India                   ZAWAR MINES  WRI1019901
# 907     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %% [markdown]
# # Features Explanation:
#     `country` : 3 character country code corresponding to the ISO 3166-1 alpha-3 specification [5]..
#     `country_long` : longer form of the country designation..
#     `name` : name or title of the power plant, generally in Romanized form
#     `gppd_idnr` : 10 or 12 character identifier for the power plant
#     `capacity_mw` : electrical generating capacity in megawatts
#     `latitude` : geolocation in decimal degrees; WGS84 (EPSG:4326)
#     `longitude` : geolocation in decimal degrees; WGS84 (EPSG:4326)
#     `primary_fuel`: energy source used in primary electricity generation or export
#     `other_fuel1` : energy source used in electricity generation or export
#     `other_fuel2`: energy source used in electricity generation or export
#     `other_fuel3` : energy source used in electricity generation or export
#     `commissioning_year`: year of plant operation, weighted by unit-capacity when data is available
#     `owner` : majority shareholder of the power plant, generally in Romanized form
#     `source`: entity reporting the data; could be an organization, report, or document, generally in Romanized form
#     `url` : web document corresponding to the `source` field
#     `geolocation_source` : attribution for geolocation information
#     `wepp_id`: a reference to a unique plant identifier in the widely-used PLATTS-WEPP database.
#     `year_of_capacity_data`: year the capacity information was reported
#     `generation_gwh_2013` : electricity generation in gigawatt-hours reported for the year 2013
#     `generation_gwh_2014` : electricity generation in gigawatt-hours reported for the year 2014
#     `generation_gwh_2015` : electricity generation in gigawatt-hours reported for the year 2015
#     `generation_gwh_2016` : electricity generation in gigawatt-hours reported for the year 2016
#     `generation_gwh_2017` : electricity generation in gigawatt-hours reported for the year 2017
#     `generation_data_source`: attribution for the reported generation information
#     `estimated_generation_gwh`: estimated electricity generation in gigawatt-hours

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
df.shape
# Out:
# (908, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   908 non-null    object
#  1   country_long              908 non-null    object
#  2   name                      908 non-null    object
#  3   gppd_idnr                 908 non-null    object
#  4   capacity_mw               908 non-null    float64
#  5   latitude                  862 non-null    float64
#  6   longitude                 862 non-null    float64
#  7   primary_fuel              908 non-null    object
#  8   other_fuel1               199 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        528 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 907
# other_fuel3                 908
# commissioning_year          380
# owner                       566
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     908
# year_of_capacity_data       388
# generation_gwh_2013         524
# generation_gwh_2014         507
# generation_gwh_2015         483
# generation_gwh_2016         471
# generation_gwh_2017         465
# generation_data_source      458
# estimated_generation_gwh    908
# dtype: int64

# %%
df.isnull().sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Observation:
#     Dataset has 908 rows and 25 columns where as it consists of 12 Object dtypes and 13 float dtypes.
#     Above graph represent the null value of the dataset.

# %% [markdown]
# # filling the null value:

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 907
# other_fuel3                 908
# commissioning_year          380
# owner                       566
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     908
# year_of_capacity_data       388
# generation_gwh_2013         524
# generation_gwh_2014         507
# generation_gwh_2015         483
# generation_gwh_2016         471
# generation_gwh_2017         465
# generation_data_source      458
# estimated_generation_gwh    908
# dtype: int64

# %%
mean_latitude=df['latitude'].mean()
df['latitude']=df['latitude'].fillna(mean_latitude)

# %%
df['latitude'].isnull().sum()
# Out:
# 0

# %%
df['longitude'].value_counts()
# Out:
# 71.6917    4
# 71.6918    3
# 72.8983    3
# 81.2875    3
# 75.8988    3
#           ..
# 72.7629    1
# 70.3961    1
# 74.2393    1
# 77.0435    1
# 77.4768    1
# Name: longitude, Length: 828, dtype: int64

# %%
mean_longitude=df['longitude'].mean()
df['longitude']=df['longitude'].fillna(mean_longitude)

# %%
df['longitude'].isnull().sum()
# Out:
# 0

# %%
df['other_fuel1'].value_counts()
# Out:
# Oil             196
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64

# %%
mode_other_fuel1=df['other_fuel1'].mode()[0]
df['other_fuel1']=df['other_fuel1'].fillna(mode_other_fuel1)

# %%
df['other_fuel2'].value_counts()
# Out:
# Oil    1
# Name: other_fuel2, dtype: int64

# %%
df['commissioning_year'].value_counts()
# Out:
# 2013.0    28
# 2015.0    26
# 2012.0    23
# 2016.0    21
# 2010.0    17
#           ..
# 1946.0     1
# 1956.0     1
# 1937.0     1
# 1959.0     1
# 1953.0     1
# Name: commissioning_year, Length: 73, dtype: int64

# %%
mean_commissioning_year=df['commissioning_year'].mean()
df['commissioning_year']=df['commissioning_year'].fillna(mean_commissioning_year)

# %%
df['owner'].value_counts()
# Out:
# Acc Acc ltd                                                    4
# Sterling Agro Industries ltd.                                  4
# Jk Cement ltd                                                  4
# SWPPL                                                          3
# Jaypee Ltd jccl)                                               3
#                                                               ..
# Sunkon Energy Private Limited                                  1
# West Bengal Energy Development Corporation Limited (WBEDCL)    1
# Energy Infratech Private Limited                               1
# K. N. Ram                                                      1
# iEnergy Wind Farms                                             1
# Name: owner, Length: 280, dtype: int64

# %%
mode_owner=df['owner'].mode()[0]
df['owner']=df['owner'].fillna(mode_owner)

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                      0
# longitude                     0
# primary_fuel                  0
# other_fuel1                   0
# other_fuel2                 907
# other_fuel3                 908
# commissioning_year            0
# owner                         0
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     908
# year_of_capacity_data       388
# generation_gwh_2013         524
# generation_gwh_2014         507
# generation_gwh_2015         483
# generation_gwh_2016         471
# generation_gwh_2017         465
# generation_data_source      458
# estimated_generation_gwh    908
# dtype: int64

# %%
df['geolocation_source'].value_counts()
# Out:
# WRI                                     766
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64

# %%
mode_geolocation_source=df['geolocation_source'].mode()[0]
df['geolocation_source']=df['geolocation_source'].fillna(mode_geolocation_source)

# %%
df['year_of_capacity_data'].value_counts()
# Out:
# 2018.0    520
# Name: year_of_capacity_data, dtype: int64

# %%
mean_year_capacity=df['year_of_capacity_data'].mean()
df['year_of_capacity_data']=df['year_of_capacity_data'].fillna(mean_year_capacity)

# %%
df['generation_gwh_2013'].value_counts()
# Out:
# 0.000000       21
# 631.777928      1
# 605.533700      1
# 8801.420000     1
# 507.897750      1
#                ..
# 2630.113350     1
# 2999.023000     1
# 246.421700      1
# 2942.810000     1
# 20.900000       1
# Name: generation_gwh_2013, Length: 364, dtype: int64

# %%
mean_generation_gwh_2013=df['generation_gwh_2013'].mean()
df['generation_gwh_2013']=df['generation_gwh_2013'].fillna(mean_generation_gwh_2013)

# %%
df['generation_gwh_2014'].value_counts()
# Out:
# 0.000000       28
# 617.789264      1
# 359.139800      1
# 7368.390000     1
# 9983.018000     1
#                ..
# 1154.342000     1
# 451.053400      1
# 3239.142900     1
# 3155.000000     1
# 3194.359820     1
# Name: generation_gwh_2014, Length: 374, dtype: int64

# %%
mean_generation_gwh_2014=df['generation_gwh_2014'].mean()
df['generation_gwh_2014']=df['generation_gwh_2014'].fillna(mean_generation_gwh_2014)

# %%
mean_generation_gwh_2015=df['generation_gwh_2015'].mean()
df['generation_gwh_2015']=df['generation_gwh_2015'].fillna(mean_generation_gwh_2015)

# %%
mean_generation_gwh_2016=df['generation_gwh_2016'].mean()
df['generation_gwh_2016']=df['generation_gwh_2016'].fillna(mean_generation_gwh_2016)

# %%
mean_generation_gwh_2017=df['generation_gwh_2017'].mean()
df['generation_gwh_2017']=df['generation_gwh_2017'].fillna(mean_generation_gwh_2017)

# %%
df['generation_data_source'].value_counts()
# Out:
# Central Electricity Authority    450
# Name: generation_data_source, dtype: int64

# %%
mode_generation_data_source=df['generation_data_source'].mode()[0]
df['generation_data_source']=df['generation_data_source'].fillna(mode_generation_data_source)

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
df1=df[['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
       'latitude', 'longitude', 'primary_fuel', 'other_fuel1', #'other_fuel2',
       #'other_fuel3', 
        'commissioning_year', 'owner', 'source', 'url',
       'geolocation_source', #'wepp_id', 
        'year_of_capacity_data',
       'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
       'generation_gwh_2016', 'generation_gwh_2017', 'generation_data_source',
       #'estimated_generation_gwh'
       ]]

# %%
df1.isnull().sum()
# Out:
# country                   0
# country_long              0
# name                      0
# gppd_idnr                 0
# capacity_mw               0
# latitude                  0
# longitude                 0
# primary_fuel              0
# other_fuel1               0
# commissioning_year        0
# owner                     0
# source                    0
# url                       0
# geolocation_source        0
# year_of_capacity_data     0
# generation_gwh_2013       0
# generation_gwh_2014       0
# generation_gwh_2015       0
# generation_gwh_2016       0
# generation_gwh_2017       0
# generation_data_source    0
# dtype: int64

# %% [markdown]
# # EDA:

# %% [markdown]
# # Univariate:

# %%
obj=[]
for i in df1.columns:
    if df1[i].dtype==object:
        obj.append(i)
print(obj)
# Out:
# ['country', 'country_long', 'name', 'gppd_idnr', 'primary_fuel', 'other_fuel1', 'owner', 'source', 'url', 'geolocation_source', 'generation_data_source']

# %%
num=[]
for j in df1.columns:
    if df1[j].dtype!=object:
        num.append(j)
print(num)
# Out:
# ['capacity_mw', 'latitude', 'longitude', 'commissioning_year', 'year_of_capacity_data', 'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017']

# %%
for i in num:
    plt.figure(figsize=(10,4))
    sns.histplot(x=df1[i],kde=True)
    plt.xlabel(f'{i}')
    plt.title(f'distribution of {i}')

# %% [markdown]
# # Observation:
#     1. Capacity_mw is skweness in nature
#     2. Latitude is normally distributed as of the same longitude too.

# %%
for i in num:
    plt.figure(figsize=(10,4))
    sns.boxplot(x=df1[i])
    plt.title(f'Boxplot of {i}')

# %% [markdown]
# # Observation:
#     Outliers are presents in all the numerical features.

# %%
df1.describe()
# Out:
#        capacity_mw    latitude   longitude  commissioning_year  \
# count   908.000000  908.000000  908.000000          908.000000
# mean    321.046378   21.196189   77.447848         1996.876894
# std     580.221767    6.088110    4.781201           12.994825
# min       0.000000    8.168900   68.644700         1927.000000
# 25%      16.837500   17.057825   74.390250         1996.876894
# 50%      60.000000   21.278850   76.978950         1996.876894
# 75%     388.125000   25.183775   79.211600         2003.000000
# max    4760.000000   34.649000   95.408000         2018.000000
#
#        year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# count                  908.0           908.000000           908.000000
# mean                  2018.0          2304.059202          2420.393316
# std                      0.0          2465.930970          2665.360236
# min                   2018.0             0.000000             0.000000
# ...

# %% [markdown]
# # Observation:
#     Right Skweness is present in capacity_mw
#     Datas are widely spreaded in generation_gwh_2013,2014,2015,2016,2017 column.
#     outliers are present in all the features.

# %%
for i in obj:
    plt.figure(figsize=(10,4))
    sns.countplot(x=df1[i])
    plt.title(f' Count of {i}')

# %% [markdown]
# # Observation:
#     Solar, Coal, Wind, Gas, Hydro, Biomass, Oil and Nuclear are the types in which coal and hydro contributed more in primary fuel column.
#     According to geolocation_source: WRI is the max using of the range and where as industry About is next to it.

# %% [markdown]
# # Bivariate:

# %%
for i in obj:
   
    sns.countplot(x=df[i],hue='primary_fuel',data=df1)
    plt.title(f'{i} Vs Primary Fuel')
    plt.show()

# %%
num
# Out:
# ['capacity_mw',
#  'latitude',
#  'longitude',
#  'commissioning_year',
#  'year_of_capacity_data',
#  'generation_gwh_2013',
#  'generation_gwh_2014',
#  'generation_gwh_2015',
#  'generation_gwh_2016',
#  'generation_gwh_2017']

# %%
for k in num:
    sns.scatterplot(x=df1[k],y=df1['capacity_mw'])
    plt.title(f'scatterplot of {k} vs capacity_mw')
    plt.show()

# %% [markdown]
# # Multivariate:

# %%
sns.pairplot(df1)

# %% [markdown]
# # LabelEncoder

# %%
obj
# Out:
# ['country',
#  'country_long',
#  'name',
#  'gppd_idnr',
#  'primary_fuel',
#  'other_fuel1',
#  'owner',
#  'source',
#  'url',
#  'geolocation_source',
#  'generation_data_source']

# %%
df1['primary_fuel'].unique()
# Out:
# array(['Solar', 'Coal', 'Wind', 'Gas', 'Hydro', 'Biomass', 'Oil',
#        'Nuclear'], dtype=object)

# %%
df1['primary_fuel']=df1['primary_fuel'].map({'Solar':1, 'Coal':2, 'Wind':3, 'Gas':4, 'Hydro':5, 'Biomass':6, 'Oil':7,
       'Nuclear':8})
# Out:
# C:\Users\ganes\AppData\Local\Temp\ipykernel_476\3332434285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['primary_fuel']=df1['primary_fuel'].map({'Solar':1, 'Coal':2, 'Wind':3, 'Gas':4, 'Hydro':5, 'Biomass':6, 'Oil':7,

# %%
df1['primary_fuel'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8], dtype=int64)

# %%
df1['other_fuel1'].unique()
# Out:
# array(['Oil', 'Cogeneration', 'Gas'], dtype=object)

# %%
df1['other_fuel1']=df['other_fuel1'].map({'Oil':1,'Cogeneration':2,'Gas':3})
# Out:
# C:\Users\ganes\AppData\Local\Temp\ipykernel_476\2173724814.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['other_fuel1']=df['other_fuel1'].map({'Oil':1,'Cogeneration':2,'Gas':3})

# %%
df1['other_fuel1'].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df1['owner'].unique()
# Out:
# array(['Solar Paces', 'Ultratech Cement ltd', 'AES', 'Acc Acc ltd',
#        'Hindustan Pvt lt', 'Dr Ssk ltd', 'Ashok Ssk ltd',
#        'Shree Sugars ltd', 'Ener-t International Ltd.',
#        'Nav Bharat Buildcon Private Limited', 'MEIL Green Power Limited',
#        'Madras Cement Limited',
#        'DDE Renewable Energy Private Limited (DREPL)',
#        'Electromech Maritech Private Limited',
#        'Finehope Allied Engineering Private Limited',
#        'Khaya Solar Projects Private Limited',
#        'Newton Solar Private Limited', 'Saidham Overseas Private Limited',
#        'Vasavi Solar Power Private Limited', 'Indian Power ltd',
#        'Ballarpur Industries ltd', 'Jk Cement ltd', 'India Ltd icl)',
#        'Bharat Petroleum Corporation Limited', 'Bhilwara Energy Limited',
#        'Ideal Projects ltd', 'Ugar Works ltd', 'Vishwanath Sugars ltd',
#        'Hothur Pvt ltd', 'Janki Corp ltd', 'Mysore Mills ltd',
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb1=LabelEncoder()
df1['owner']=lb1.fit_transform(df1['owner'])
# Out:
# C:\Users\ganes\AppData\Local\Temp\ipykernel_476\90240817.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['owner']=lb1.fit_transform(df1['owner'])

# %%
df1['owner'].unique()
# Out:
# array([229, 258,   2,   5,  89,  49,  14, 219,  53, 160, 132, 135,  41,
#         52,  58, 117, 161, 209, 265, 100,  20, 108,  97,  24,  26,  96,
#        256, 268,  93, 105, 152, 238, 262, 211,  25,  28, 101,  48,   3,
#         54,  77, 170, 180,  92, 147,  66, 123, 126,   4,   6, 134, 191,
#         30,  91,  84, 142,  40, 136,  35,  98,   8, 196,  31,  43,  44,
#        149, 222, 110, 215, 103,  73, 275, 212, 257, 210,  13, 194, 125,
#        231,  51,  61,  83,  34,  62, 129,  21,  74, 173, 236, 175, 158,
#         72, 278, 218, 226,  32,  12, 228, 106, 181, 199,  90,  85,  57,
#         95,  60,  87, 114,  70, 107, 239, 274,  55, 111,  36, 118, 277,
#        143,  67, 260, 233,  88, 223, 122,  22, 167,  86,  45, 112,  65,
#        113,  29, 237, 115,  17,  37, 213,  82,  59, 165, 241,   1, 259,
#        273,  39, 183, 119, 249, 131, 124, 247, 130,  16,  56,  94, 214,
#        127, 128, 137,  23, 138, 139, 140, 141,  11, 201, 109, 133,  79,
# ...

# %%
df1['geolocation_source'].unique()
# Out:
# array(['National Renewable Energy Laboratory', 'WRI', 'Industry About'],
#       dtype=object)

# %%
df1['geolocation_source']=df1['geolocation_source'].map({'National Renewable Energy Laboratory':1, 'WRI':2, 'Industry About':3})
# Out:
# C:\Users\ganes\AppData\Local\Temp\ipykernel_476\1053435832.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['geolocation_source']=df1['geolocation_source'].map({'National Renewable Energy Laboratory':1, 'WRI':2, 'Industry About':3})

# %%
df1['geolocation_source'].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df1.commissioning_year.value_counts()
# Out:
# 1996.876894    380
# 2013.000000     28
# 2015.000000     26
# 2012.000000     23
# 2016.000000     21
#               ...
# 1946.000000      1
# 1956.000000      1
# 1937.000000      1
# 1959.000000      1
# 1953.000000      1
# Name: commissioning_year, Length: 74, dtype: int64

# %%
df1['commissioning_year']=df1['commissioning_year'].astype(int)
# Out:
# C:\Users\ganes\AppData\Local\Temp\ipykernel_476\3935516301.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['commissioning_year']=df1['commissioning_year'].astype(int)

# %%
df1.commissioning_year.value_counts()
# Out:
# 1996    393
# 2013     28
# 2015     26
# 2012     23
# 2016     21
#        ...
# 1946      1
# 1956      1
# 1937      1
# 1959      1
# 1953      1
# Name: commissioning_year, Length: 73, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 908 non-null    object
#  1   country_long            908 non-null    object
#  2   name                    908 non-null    object
#  3   gppd_idnr               908 non-null    object
#  4   capacity_mw             908 non-null    float64
#  5   latitude                908 non-null    float64
#  6   longitude               908 non-null    float64
#  7   primary_fuel            908 non-null    int64
#  8   other_fuel1             908 non-null    int64
#  9   commissioning_year      908 non-null    int32
#  10  owner                   908 non-null    int32
#  11  source                  908 non-null    object
#  12  url                     908 non-null    object
#  13  geolocation_source      908 non-null    int64
# ...

# %%
df1.year_of_capacity_data.value_counts()
# Out:
# 2018.0    908
# Name: year_of_capacity_data, dtype: int64

# %%
df1.primary_fuel.unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8], dtype=int64)

# %%
df1.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1',
#        'commissioning_year', 'owner', 'source', 'url', 'geolocation_source',
#        'year_of_capacity_data', 'generation_gwh_2013', 'generation_gwh_2014',
#        'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017',
#        'generation_data_source'],
#       dtype='object')

# %%
df2=df1[[#'country', 'country_long', 'name', 'gppd_idnr', 
        'capacity_mw',
       'latitude', 'longitude', 'primary_fuel', 'other_fuel1',
       'commissioning_year', 'owner', #'source', 'url', 
      'geolocation_source',
       #'year_of_capacity_data', 
    'generation_gwh_2013', 'generation_gwh_2014',
       'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017',
       #'generation_data_source'
]]

# %% [markdown]
# # Removing Outliers

# %%
df2.plot(kind='box',subplots=True,layout=(11,8))
# Out:
# capacity_mw              AxesSubplot(0.125,0.820769;0.0824468x0.0592308)
# latitude               AxesSubplot(0.223936,0.820769;0.0824468x0.0592...
# longitude              AxesSubplot(0.322872,0.820769;0.0824468x0.0592...
# primary_fuel           AxesSubplot(0.421809,0.820769;0.0824468x0.0592...
# other_fuel1            AxesSubplot(0.520745,0.820769;0.0824468x0.0592...
# commissioning_year     AxesSubplot(0.619681,0.820769;0.0824468x0.0592...
# owner                  AxesSubplot(0.718617,0.820769;0.0824468x0.0592...
# geolocation_source     AxesSubplot(0.817553,0.820769;0.0824468x0.0592...
# generation_gwh_2013      AxesSubplot(0.125,0.749692;0.0824468x0.0592308)
# generation_gwh_2014    AxesSubplot(0.223936,0.749692;0.0824468x0.0592...
# generation_gwh_2015    AxesSubplot(0.322872,0.749692;0.0824468x0.0592...
# generation_gwh_2016    AxesSubplot(0.421809,0.749692;0.0824468x0.0592...
# generation_gwh_2017    AxesSubplot(0.520745,0.749692;0.0824468x0.0592...
# dtype: object

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df2))
z
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0       0.549311  1.148396   0.880420      1.367859     0.055395
# 1       0.384628  0.586730   0.594079      0.790446     0.055395
# 2       0.486024  0.116292   1.689763      0.213032     0.055395
# 3       0.320824  0.439625   2.911407      0.364381     0.055395
# 4       2.550350  0.125578   1.038230      0.790446     0.055395
# ..           ...       ...        ...           ...          ...
# 903     2.205464  0.805503   0.019053      0.790446     0.055395
# 904     0.548448  1.364556   0.150161      1.367859     0.055395
# 905     0.509649  0.972987   0.390650      0.213032     0.055395
# 906     0.415667  0.518313   0.774322      0.790446     0.055395
# 907     0.525169  1.850820   0.006059      0.213032     0.055395
#
#      commissioning_year     owner  geolocation_source  generation_gwh_2013  \
# 0              1.115062  2.096722            3.260228             0.000000
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  0,  15,  15,  15,  15, 144, 144, 144, 144, 144, 144, 159, 159,
#        180, 184, 199, 200, 210, 210, 210, 210, 210, 210, 222, 240, 245,
#        246, 309, 309, 309, 309, 309, 309, 324, 334, 341, 343, 361, 364,
#        365, 365, 365, 365, 365, 365, 372, 376, 389, 417, 428, 445, 455,
#        479, 483, 485, 494, 494, 494, 494, 494, 494, 495, 495, 495, 495,
#        495, 495, 500, 520, 530, 533, 539, 542, 547, 575, 584, 602, 622,
#        639, 649, 649, 649, 649, 649, 649, 658, 658, 658, 658, 658, 658,
#        696, 696, 696, 696, 696, 707, 710, 722, 722, 722, 722, 725, 725,
#        725, 725, 725, 727, 727, 727, 727, 727, 727, 729, 787, 787, 787,
#        787, 787, 787, 789, 808, 809, 809, 809, 809, 809, 812, 814, 818,
#        819, 848, 849, 849, 881, 881, 881, 881, 881, 881], dtype=int64), array([ 7,  0, 10, 11, 12,  0,  8,  9, 10, 11, 12,  8,  9,  2,  2,  7,  7,
#         0,  8,  9, 10, 11, 12,  5,  2,  2,  7,  0,  8,  9, 10, 11, 12,  2,
# ...

# %%
df3=df2[(z<3).all (axis=1)]

# %%
df3.shape
# Out:
# (843, 13)

# %%
df2_cor=df2.corr()

# %%
plt.figure(figsize=(10,4))
sns.heatmap(df2_cor,annot=True)
plt.show()

# %% [markdown]
# # For Prediction of primary_fuel(classification)

# %% [markdown]
# # Scenario:1 Without Removing Outliers

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x_class=df2.drop(['primary_fuel'],axis=1)

# %%
y_class=df2['primary_fuel']

# %%
def vifcheck(x_class):
    vif=pd.DataFrame()
    vif['Original']=x_class.columns
    vif['Variance_inflation_factor']=[variance_inflation_factor(x_class.values,i) for i in range(x_class.shape[1])]
    print(vif)

# %%
vifcheck(x_class)
# Out:
#                Original  Variance_inflation_factor
# 0           capacity_mw                   4.370767
# 1              latitude                  13.870450
# 2             longitude                 303.417734
# 3           other_fuel1                 103.182170
# 4    commissioning_year                 505.393806
# 5                 owner                   2.142944
# 6    geolocation_source                  48.098357
# 7   generation_gwh_2013                  29.407855
# 8   generation_gwh_2014                  62.169510
# 9   generation_gwh_2015                  47.682916
# 10  generation_gwh_2016                  59.063999
# 11  generation_gwh_2017                  28.615156

# %%
x_class.columns
# Out:
# Index(['capacity_mw', 'latitude', 'longitude', 'other_fuel1',
#        'commissioning_year', 'owner', 'geolocation_source',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017'],
#       dtype='object')

# %%
x_class=x_class[['capacity_mw', 'latitude', 'longitude', 
                 'other_fuel1',
       #'commissioning_year', 
                 #'owner', #'geolocation_source',
       'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
       'generation_gwh_2016', 'generation_gwh_2017']]

# %%
vifcheck(x_class)
# Out:
#               Original  Variance_inflation_factor
# 0          capacity_mw                   3.233631
# 1             latitude                  12.863659
# 2            longitude                  81.350093
# 3          other_fuel1                  73.499918
# 4  generation_gwh_2013                  29.386797
# 5  generation_gwh_2014                  62.144579
# 6  generation_gwh_2015                  47.613262
# 7  generation_gwh_2016                  58.949206
# 8  generation_gwh_2017                  28.124417

# %%
from sklearn.preprocessing import StandardScaler

# %%
std1=StandardScaler()
x_class_scaled=pd.DataFrame(std1.fit_transform(x_class),columns=x_class.columns)

# %%
y_class.value_counts()
# Out:
# 2    259
# 5    250
# 1    127
# 3    123
# 4     69
# 6     50
# 7     21
# 8      9
# Name: primary_fuel, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %%
smt1=SMOTE()
x_class_sampled,y_class_sampled=smt1.fit_resample(x_class,y_class)

# %%
y_class_sampled.value_counts()
# Out:
# 1    259
# 2    259
# 3    259
# 4    259
# 5    259
# 6    259
# 7    259
# 8    259
# Name: primary_fuel, dtype: int64

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split,cross_val_score

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
maxAcc=0
maxRs=0
for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x_class_sampled,y_class_sampled,test_size=.30,random_state=i)
    rf=RandomForestClassifier()
    rf.fit(x_train,y_train)
    pred=rf.predict(x_test)
    accuracy=accuracy_score(y_test,pred)
    if accuracy>maxAcc:
        maxAcc=accuracy
        maxRs=i
print(f'Best Accuracy for the sampled date is {maxAcc} and randomstate is{maxRs}')
# Out:
# Best Accuracy for the sampled date is 0.8713826366559485 and randomstate is18

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
maxAcc=0
maxRs=0
for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x_class_sampled,y_class_sampled,test_size=.30,random_state=i)
    et=ExtraTreesClassifier()
    et.fit(x_train,y_train)
    pred=et.predict(x_test)
    accuracy=accuracy_score(y_test,pred)
    if accuracy>maxAcc:
        maxAcc=accuracy
        maxRs=i
print(f'Best Accuracy for the sampled date is {maxAcc} and randomstate is{maxRs}')
# Out:
# Best Accuracy for the sampled date is 0.8762057877813505 and randomstate is114

# %%
def modelcheck(models,x,y):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x,y,test_size=.30,random_state=rs)
        
    for model in models:
          
            print(f'Model:{model.__class__.__name__} with random_state={rs}')
            model.fit(x1_train,y1_train)
            pred_model=model.predict(x1_test)
            accuracy=accuracy_score(y1_test,pred_model)
            print(f'Accuracy:{accuracy}')
            print('Confusion_matrix:',confusion_matrix(y1_test,pred_model))
            print('Classification_report:',classification_report(y1_test,pred_model))
            model_cross_score=cross_val_score(model,x,y,cv=5)
            print(model_cross_score)
            print(model_cross_score.mean())
        
            difference= accuracy-model_cross_score.mean()
            print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
        
rf1=RandomForestClassifier()
dtc1=DecisionTreeClassifier()
knn1=KNeighborsClassifier()
et1=ExtraTreesClassifier()
ada1=AdaBoostClassifier(algorithm='SAMME')
gb1=GradientBoostingClassifier()
x=x_class_sampled
y=y_class_sampled
rs=295
models=[rf1,dtc1,knn1,et1,ada1,gb1]
modelcheck(models,x,y)
# Out:
# Model:RandomForestClassifier with random_state=295
# Accuracy:0.8295819935691319
# Confusion_matrix: [[71  2  5  1  0  3  0  0]
#  [ 2 45  5  7  6  4  0  4]
#  [ 4  0 58  0  1  4  1  0]
#  [ 1  6  2 63  2  2  6  5]
#  [ 1  2  4 10 61  2  4  0]
#  [ 2  0  3  0  0 66  0  0]
#  [ 0  1  0  0  1  0 86  0]
#  [ 1  2  0  0  0  0  0 66]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       0.87      0.87      0.87        82
#            2       0.78      0.62      0.69        73
#            3       0.75      0.85      0.80        68
#            4       0.78      0.72      0.75        87
#            5       0.86      0.73      0.79        84
#            6       0.81      0.93      0.87        71
#            7       0.89      0.98      0.93        88
#            8       0.88      0.96      0.92        69
#
#     accuracy                           0.83       622
#    macro avg       0.83      0.83      0.83       622
# ...

# %% [markdown]
# # Scenario 2: After removing outliers

# %%
x_class2=df3.drop(['primary_fuel'],axis=1)

# %%
y_class2=df3['primary_fuel']

# %%
def vifcheck1(x_class2):
    vif=pd.DataFrame()
    vif['Original']=x_class2.columns
    vif['Variance_inflation_factor']=[variance_inflation_factor(x_class2.values,i) for i in range(x_class2.shape[1])]
    print(vif)

# %%
vifcheck1(x_class2)
# Out:
#                Original  Variance_inflation_factor
# 0           capacity_mw                   2.139033
# 1              latitude                   1.084790
# 2             longitude                   1.203751
# 3           other_fuel1               36420.689752
# 4    commissioning_year                   1.165779
# 5                 owner                   1.504577
# 6    geolocation_source                   1.300992
# 7   generation_gwh_2013                   7.604957
# 8   generation_gwh_2014                  10.727489
# 9   generation_gwh_2015                   9.572904
# 10  generation_gwh_2016                  11.464208
# 11  generation_gwh_2017                   6.553170

# %%
x_class2.columns
# Out:
# Index(['capacity_mw', 'latitude', 'longitude', 'other_fuel1',
#        'commissioning_year', 'owner', 'geolocation_source',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017'],
#       dtype='object')

# %%
x_class2=x_class2[['capacity_mw', 'latitude', 'longitude', #'other_fuel1',
       'commissioning_year', 'owner', 'geolocation_source',
       'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
       'generation_gwh_2016', 'generation_gwh_2017']]

# %%
vifcheck1(x_class2)
# Out:
#                Original  Variance_inflation_factor
# 0           capacity_mw                   2.842889
# 1              latitude                  13.845828
# 2             longitude                 404.213689
# 3    commissioning_year                 502.760993
# 4                 owner                   2.242878
# 5    geolocation_source                  50.729759
# 6   generation_gwh_2013                  24.858448
# 7   generation_gwh_2014                  33.972125
# 8   generation_gwh_2015                  28.516498
# 9   generation_gwh_2016                  33.159561
# 10  generation_gwh_2017                  19.030643

# %%
x_class2=x_class2[['capacity_mw', 'latitude', 'longitude', #'other_fuel1',
       #'commissioning_year', 
                   'owner', 'geolocation_source',
       'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
       'generation_gwh_2016', 'generation_gwh_2017']]

# %%
vifcheck1(x_class2)
# Out:
#               Original  Variance_inflation_factor
# 0          capacity_mw                   2.816673
# 1             latitude                  13.695263
# 2            longitude                  39.473757
# 3                owner                   2.226440
# 4   geolocation_source                  43.140520
# 5  generation_gwh_2013                  24.846041
# 6  generation_gwh_2014                  33.935729
# 7  generation_gwh_2015                  28.437235
# 8  generation_gwh_2016                  33.095772
# 9  generation_gwh_2017                  19.001265

# %%
smt2=SMOTE()
x_class2_sampled,y_class2_sampled=smt2.fit_resample(x_class2,y_class2)

# %%
y_class2_sampled.value_counts()
# Out:
# 2    236
# 3    236
# 4    236
# 5    236
# 6    236
# 1    236
# 7    236
# 8    236
# Name: primary_fuel, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
maxAcc=0
maxRs=0
for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x_class2_sampled,y_class2_sampled,test_size=.30,random_state=i)
    rf=RandomForestClassifier()
    rf.fit(x_train,y_train)
    pred=rf.predict(x_test)
    accuracy=accuracy_score(y_test,pred)
    if accuracy>maxAcc:
        maxAcc=accuracy
        maxRs=i
print(f'Best Accuracy for the sampled date is {maxAcc} and randomstate is{maxRs}')
# Out:
# Best Accuracy for the sampled date is 0.8977072310405644 and randomstate is12

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
maxAcc=0
maxRs=0
for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x_class2_sampled,y_class2_sampled,test_size=.30,random_state=i)
    et=ExtraTreesClassifier()
    et.fit(x_train,y_train)
    pred=et.predict(x_test)
    accuracy=accuracy_score(y_test,pred)
    if accuracy>maxAcc:
        maxAcc=accuracy
        maxRs=i
print(f'Best Accuracy for the sampled date is {maxAcc} and randomstate is{maxRs}')
# Out:
# Best Accuracy for the sampled date is 0.9065255731922398 and randomstate is108

# %%
def modelcheck(models,x,y):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x,y,test_size=.30,random_state=rs)
        
    for model in models:
          
            print(f'Model:{model.__class__.__name__} with random_state={rs}')
            model.fit(x1_train,y1_train)
            pred_model=model.predict(x1_test)
            accuracy=accuracy_score(y1_test,pred_model)
            print(f'Accuracy:{accuracy}')
            print('Confusion_matrix:',confusion_matrix(y1_test,pred_model))
            print('Classification_report:',classification_report(y1_test,pred_model))
            model_cross_score=cross_val_score(model,x,y,cv=5)
            print(model_cross_score)
            print(model_cross_score.mean())
        
            difference= accuracy-model_cross_score.mean()
            print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
        
rf2=RandomForestClassifier()
dtc2=DecisionTreeClassifier()
knn2=KNeighborsClassifier()
et2=ExtraTreesClassifier()
ada2=AdaBoostClassifier(algorithm='SAMME')
gb2=GradientBoostingClassifier()
x=x_class2_sampled
y=y_class2_sampled
rs=39
models=[rf2,dtc2,knn2,et2,ada2,gb2]
modelcheck(models,x,y)
# Out:
# Model:RandomForestClassifier with random_state=39
# Accuracy:0.8818342151675485
# Confusion_matrix: [[61  1  0  0  0  1  0  0]
#  [ 0 45  0  9  4  2  1  5]
#  [ 0  1 67  0  3  1  1  0]
#  [ 0  3  2 63  0  1  3  2]
#  [ 0  6  0 14 53  0  1  0]
#  [ 0  1  3  0  0 70  1  0]
#  [ 0  0  1  0  0  0 81  0]
#  [ 0  0  0  0  0  0  0 60]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       1.00      0.97      0.98        63
#            2       0.79      0.68      0.73        66
#            3       0.92      0.92      0.92        73
#            4       0.73      0.85      0.79        74
#            5       0.88      0.72      0.79        74
#            6       0.93      0.93      0.93        75
#            7       0.92      0.99      0.95        82
#            8       0.90      1.00      0.94        60
#
#     accuracy                           0.88       567
#    macro avg       0.88      0.88      0.88       567
# ...

# %%
x2_class_train,x2_class_test,y2_class_train,y2_class_test=train_test_split(x_class2_sampled,y_class2_sampled,test_size=.30,random_state=39)

# %%
et2_class=ExtraTreesClassifier()
et2_class.fit(x2_class_train,y2_class_train)
# Out:
# ExtraTreesClassifier()

# %%
et2_class_pred=et2_class.predict(x2_class_test)

# %%
accuracy=accuracy_score(y2_class_test,et2_class_pred)
print(f'Accuracy:{accuracy}')
print('Confusion_matrix:',confusion_matrix(y2_class_test,et2_class_pred))
print('Classification_report:',classification_report(y2_class_test,et2_class_pred))
et2_class_cross_score=cross_val_score(et2_class,x_class2_sampled,y_class2_sampled,cv=5)
print(et2_class_cross_score)
print(et2_class_cross_score.mean())
        
difference= accuracy-et2_class_cross_score.mean()
print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
# Out:
# Accuracy:0.8941798941798942
# Confusion_matrix: [[61  1  0  0  0  1  0  0]
#  [ 0 51  1  6  1  0  1  6]
#  [ 0  0 67  0  3  2  1  0]
#  [ 0  4  3 62  0  1  4  0]
#  [ 0  8  0 12 53  0  1  0]
#  [ 0  0  3  0  0 72  0  0]
#  [ 0  0  1  0  0  0 81  0]
#  [ 0  0  0  0  0  0  0 60]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       1.00      0.97      0.98        63
#            2       0.80      0.77      0.78        66
#            3       0.89      0.92      0.91        73
#            4       0.78      0.84      0.81        74
#            5       0.93      0.72      0.81        74
#            6       0.95      0.96      0.95        75
#            7       0.92      0.99      0.95        82
#            8       0.91      1.00      0.95        60
#
#     accuracy                           0.89       567
#    macro avg       0.90      0.90      0.89       567
# weighted avg       0.90      0.89      0.89       567
#
# ...

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# Initialize GridSearchCV with the ExtraTreesRegressor and parameter grid
grid_search_etr = GridSearchCV(estimator=et2_class, param_grid=param_grid, cv=5, n_jobs=-1, scoring='neg_mean_squared_error')

# Fit GridSearchCV to the training data
grid_search_etr.fit(x2_class_train, y2_class_train)

# Get the best parameters and best score
best_params_etr = grid_search_etr.best_params_
best_score_etr = grid_search_etr.best_score_

print("Best Parameters for ExtraTreesRegressor:", best_params_etr)
print("Best Score for ExtraTreesRegressor:", best_score_etr)
# Out:
# C:\Users\ganes\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 540 fits failed out of a total of 1620.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 438 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ganes\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ganes\anaconda3\lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ganes\anaconda3\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
et2h_class=ExtraTreesClassifier(max_depth= 30, max_features= 'log2', min_samples_leaf= 1, min_samples_split= 2, n_estimators= 200)

# %%
et2h_class.fit(x2_class_train,y2_class_train)
# Out:
# ExtraTreesClassifier(max_depth=30, max_features='log2', n_estimators=200)

# %%
et2h_class_pred=et2h_class.predict(x2_class_test)

# %%
accuracy=accuracy_score(y2_class_test,et2h_class_pred)
print(f'Accuracy:{accuracy}')
print('Confusion_matrix:',confusion_matrix(y2_class_test,et2h_class_pred))
print('Classification_report:',classification_report(y2_class_test,et2h_class_pred))
et2h_class_cross_score=cross_val_score(et2h_class,x_class2_sampled,y_class2_sampled,cv=5)
print(et2h_class_cross_score)
print(et2h_class_cross_score.mean())
        
difference= accuracy-et2h_class_cross_score.mean()
print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
# Out:
# Accuracy:0.8959435626102292
# Confusion_matrix: [[61  1  0  0  0  1  0  0]
#  [ 0 50  1  6  1  1  1  6]
#  [ 0  0 68  0  3  1  1  0]
#  [ 0  4  3 62  0  1  4  0]
#  [ 0  9  0 11 53  0  1  0]
#  [ 0  0  2  0  0 73  0  0]
#  [ 0  0  1  0  0  0 81  0]
#  [ 0  0  0  0  0  0  0 60]]
# Classification_report:               precision    recall  f1-score   support
#
#            1       1.00      0.97      0.98        63
#            2       0.78      0.76      0.77        66
#            3       0.91      0.93      0.92        73
#            4       0.78      0.84      0.81        74
#            5       0.93      0.72      0.81        74
#            6       0.95      0.97      0.96        75
#            7       0.92      0.99      0.95        82
#            8       0.91      1.00      0.95        60
#
#     accuracy                           0.90       567
#    macro avg       0.90      0.90      0.89       567
# weighted avg       0.90      0.90      0.89       567
#
# ...

# %%
import joblib

# %%
print(type(joblib))
# Out:
# <class 'module'>

# %%
joblib.dump(et2h_class,'global_power_plant_primaryfuel_analysis.pkl')
# Out:
# ['global_power_plant_primaryfuel_analysis.pkl']

# %%
model_class=joblib.load('global_power_plant_primaryfuel_analysis.pkl')
prediction=model_class.predict(x2_class_test)

# %%
a=np.array(y2_class_test)
df_test_class=pd.DataFrame()
df_test_class['original']=a
df_test_class['predict']=prediction
df_test_class
# Out:
#      original  predict
# 0           6        6
# 1           4        4
# 2           7        7
# 3           1        1
# 4           7        7
# ..        ...      ...
# 562         3        3
# 563         1        1
# 564         2        2
# 565         4        4
# 566         6        6
#
# [567 rows x 2 columns]

# %% [markdown]
# # For Prediction capacity_mw(regression)

# %% [markdown]
# # Scenario:1 without removing outliers

# %%
df4=df2

# %%
std2=StandardScaler()
df4_scaled=pd.DataFrame(std2.fit_transform(df4),columns=df4.columns)

# %%
x1_reg=df4_scaled.drop(['capacity_mw'],axis=1)
y1_reg=df4_scaled['capacity_mw']

# %%
def vifcheck3(x1_reg):
    vif=pd.DataFrame()
    vif['Original']=x1_reg.columns
    vif['Variance_inflation_factor']=[variance_inflation_factor(x1_reg.values,i) for i in range(x1_reg.shape[1])]
    print(vif)

# %%
vifcheck3(x1_reg)
# Out:
#                Original  Variance_inflation_factor
# 0              latitude                   1.065994
# 1             longitude                   1.145481
# 2          primary_fuel                   1.651024
# 3           other_fuel1                   1.017715
# 4    commissioning_year                   1.166145
# 5                 owner                   1.245973
# 6    geolocation_source                   1.603942
# 7   generation_gwh_2013                  15.736644
# 8   generation_gwh_2014                  34.066767
# 9   generation_gwh_2015                  27.833156
# 10  generation_gwh_2016                  34.203749
# 11  generation_gwh_2017                  15.249779

# %%
x1_reg.columns
# Out:
# Index(['latitude', 'longitude', 'primary_fuel', 'other_fuel1',
#        'commissioning_year', 'owner', 'geolocation_source',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017'],
#       dtype='object')

# %%
x1_reg=x1_reg[['latitude', 'longitude', 'primary_fuel', #'other_fuel1',
       'commissioning_year', #'owner', 
               'geolocation_source',
       'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
       'generation_gwh_2016', 'generation_gwh_2017']]

# %%
vifcheck3(x1_reg)
# Out:
#               Original  Variance_inflation_factor
# 0             latitude                   1.047262
# 1            longitude                   1.076466
# 2         primary_fuel                   1.634191
# 3   commissioning_year                   1.164848
# 4   geolocation_source                   1.509398
# 5  generation_gwh_2013                  15.734621
# 6  generation_gwh_2014                  34.062382
# 7  generation_gwh_2015                  27.831157
# 8  generation_gwh_2016                  34.127257
# 9  generation_gwh_2017                  15.183958

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
maxRs=0
max_Acc=0

for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x1_reg,y1_reg,test_size=.30,random_state=i)
    rf=RandomForestRegressor()
    rf.fit(x_train,y_train)
    pred=rf.predict(x_test)
    acc=r2_score(y_test,pred)
    error=np.sqrt(mean_squared_error(y_test,pred))
    if acc>max_Acc:
        maxRs=i
        max_Acc=acc
        
print(f'Best score{max_Acc} and least error{error} in randomstate{maxRs}')
# Out:
# Best score0.9310113842999236 and least error0.4107057821979391 in randomstate107

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
maxRs=0
max_Acc=0

for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x1_reg,y1_reg,test_size=.30,random_state=i)
    etr=ExtraTreesRegressor()
    etr.fit(x_train,y_train)
    pred=etr.predict(x_test)
    acc=r2_score(y_test,pred)
    error=np.sqrt(mean_squared_error(y_test,pred))
    if acc>max_Acc:
        maxRs=i
        max_Acc=acc
        
print(f'Best score{max_Acc} and least error{error} in randomstate{maxRs}')
# Out:
# Best score0.933824226569282 and least error0.3855433029305819 in randomstate107

# %%
def modelcheck1(models,x,y):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x,y,test_size=.30,random_state=rs)
        
    for model in models:
          
            print(f'Model:{model.__class__.__name__} with random_state={rs}')
            model.fit(x1_train,y1_train)
            pred_model=model.predict(x1_test)
            accuracy=r2_score(y1_test,pred_model)
            print(f'Accuracy:{accuracy}')
            mse=mean_squared_error(y1_test,pred_model)
            print('Meansquare_error',mse)
            print('RootMeansquare:',np.sqrt(mse))
            model_cross_score=cross_val_score(model,x,y,cv=5)
            print(model_cross_score)
            print(model_cross_score.mean())
        
            difference= accuracy-model_cross_score.mean()
            print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
        
lin=LinearRegression()
rf1=RandomForestRegressor()
dtc1=DecisionTreeRegressor()
knn1=KNeighborsRegressor()
et1=ExtraTreesRegressor()
ada1=AdaBoostRegressor()
gb1=GradientBoostingRegressor()
for j in [0.1,0.01,0.001]:
    ls1=Lasso(alpha=j)
for k in [0.1,0.01,0.001]:
    rd1=Ridge(alpha=k)
x=x1_reg
y=y1_reg
rs=107
models=[lin,rf1,dtc1,knn1,et1,ada1,gb1,ls1,rd1]
modelcheck1(models,x,y)
# Out:
# Model:LinearRegression with random_state=107
# Accuracy:0.7766858809845912
# Meansquare_error 0.2589160582188202
# RootMeansquare: 0.5088379488784422
# [0.5537572  0.43434585 0.65123956 0.6653717  0.72567053]
# 0.606076965174245
# Difference Between Accuracy and Cross_val_score mean: 0.1706089158103462
#
# Model:RandomForestRegressor with random_state=107
# Accuracy:0.9220155692271791
# Meansquare_error 0.09041712860414362
# RootMeansquare: 0.30069441066329056
# [0.82281877 0.84481092 0.8127212  0.85878275 0.90054749]
# 0.8479362244906794
# Difference Between Accuracy and Cross_val_score mean: 0.07407934473649969
#
# Model:DecisionTreeRegressor with random_state=107
# Accuracy:0.8488279107703609
# Meansquare_error 0.17527275762327052
# RootMeansquare: 0.4186558940505562
# [0.68024416 0.63352733 0.71519939 0.68615104 0.82846171]
# 0.7087167254082105
# Difference Between Accuracy and Cross_val_score mean: 0.1401111853621504
#
# Model:KNeighborsRegressor with random_state=107
# ...

# %%
x1_reg_train,x1_reg_test,y1_reg_train,y1_reg_test=train_test_split(x1_reg,y1_reg,test_size=0.3,random_state=107)

# %%
et1_reg=ExtraTreesRegressor()
et1_reg.fit(x1_reg_train,y1_reg_train)
# Out:
# ExtraTreesRegressor()

# %%
et1_reg_pred=et1_reg.predict(x1_reg_test)

# %%
accuracy=r2_score(y1_reg_test,et1_reg_pred)
print(f'Accuracy:{accuracy}')
mse=mean_squared_error(y1_reg_test,et1_reg_pred)
print('Meansquare_error',mse)
print('RootMeansquare:',np.sqrt(mse))
et1_reg_cross_score=cross_val_score(et1_reg,x,y,cv=5)
print(et1_reg_cross_score)
print(et1_reg_cross_score.mean())
        
difference= accuracy-et1_reg_cross_score.mean()
print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
# Out:
# Accuracy:0.9367877983010117
# Meansquare_error 0.07328983123590925
# RootMeansquare: 0.2707209471686837
# [0.86065251 0.85503908 0.8145205  0.86663114 0.90248868]
# 0.8598663826182118
# Difference Between Accuracy and Cross_val_score mean: 0.07692141568279987

# %% [markdown]
# # Scenario:2 Removing outliers

# %%
df5=df3

# %%
std3=StandardScaler()
df5_scaled=pd.DataFrame(std3.fit_transform(df5),columns=df5.columns)

# %%
x2_reg=df5_scaled.drop(['capacity_mw'],axis=1)

# %%
y2_reg=df5_scaled['capacity_mw']

# %%
def vifcheck4(x2_reg):
    vif=pd.DataFrame()
    vif['Original']=x2_reg.columns
    vif['Variance_inflation_factor']=[variance_inflation_factor(x2_reg.values,i) for i in range(x2_reg.shape[1])]
    print(vif)

# %%
vifcheck4(x2_reg)
# Out:
#                Original  Variance_inflation_factor
# 0              latitude                   1.085044
# 1             longitude                   1.195944
# 2          primary_fuel                   1.742731
# 3           other_fuel1                        NaN
# 4    commissioning_year                   1.175721
# 5                 owner                   1.262159
# 6    geolocation_source                   1.788560
# 7   generation_gwh_2013                   7.524357
# 8   generation_gwh_2014                  10.729312
# 9   generation_gwh_2015                   9.515681
# 10  generation_gwh_2016                  11.376003
# 11  generation_gwh_2017                   6.286906
# C:\Users\ganes\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1738: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.uncentered_tss

# %%
x2_reg.columns
# Out:
# Index(['latitude', 'longitude', 'primary_fuel', 'other_fuel1',
#        'commissioning_year', 'owner', 'geolocation_source',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017'],
#       dtype='object')

# %%
x2_reg=x2_reg[['latitude', 'longitude', 'primary_fuel', #'other_fuel1',
       'commissioning_year', #'owner', 
               #'geolocation_source',
       'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
       'generation_gwh_2016', 'generation_gwh_2017']]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
maxRs=0
max_Acc=0

for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x2_reg,y2_reg,test_size=.30,random_state=i)
    rfr=RandomForestRegressor()
    rfr.fit(x_train,y_train)
    pred=rfr.predict(x_test)
    acc=r2_score(y_test,pred)
    error=np.sqrt(mean_squared_error(y_test,pred))
    if acc>max_Acc:
        maxRs=i
        max_Acc=acc
        
print(f'Best score{max_Acc} and least error{error} in randomstate{maxRs}')
# Out:
# Best score0.8755513695447317 and least error0.48479060276070784 in randomstate64

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
maxRs=0
max_Acc=0

for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x2_reg,y2_reg,test_size=.30,random_state=i)
    etr=ExtraTreesRegressor()
    etr.fit(x_train,y_train)
    pred=etr.predict(x_test)
    acc=r2_score(y_test,pred)
    error=np.sqrt(mean_squared_error(y_test,pred))
    if acc>max_Acc:
        maxRs=i
        max_Acc=acc
        
print(f'Best score{max_Acc} and least error{error} in randomstate{maxRs}')
# Out:
# Best score0.8938298423607177 and least error0.4821213302401406 in randomstate25

# %%
def modelcheck2(models,x,y):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x,y,test_size=.30,random_state=rs)
        
    for model in models:
          
            print(f'Model:{model.__class__.__name__} with random_state={rs}')
            model.fit(x1_train,y1_train)
            pred_model=model.predict(x1_test)
            accuracy=r2_score(y1_test,pred_model)
            print(f'Accuracy:{accuracy}')
            mse=mean_squared_error(y1_test,pred_model)
            print('Meansquare_error',mse)
            print('RootMeansquare:',np.sqrt(mse))
            model_cross_score=cross_val_score(model,x,y,cv=5)
            print(model_cross_score)
            print(model_cross_score.mean())
        
            difference= accuracy-model_cross_score.mean()
            print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
        
lin2=LinearRegression()
rf2=RandomForestRegressor()
dtc2=DecisionTreeRegressor()
knn2=KNeighborsRegressor()
et2=ExtraTreesRegressor()
ada2=AdaBoostRegressor()
gb2=GradientBoostingRegressor()
for j in [0.1,0.01,0.001]:
    ls2=Lasso(alpha=j)
for k in [0.1,0.01,0.001]:
    rd2=Ridge(alpha=k)
x=x2_reg
y=y2_reg
rs=25
models=[lin2,rf2,dtc2,knn2,et2,ada2,gb2,ls2,rd2]
modelcheck1(models,x,y)
# Out:
# Model:LinearRegression with random_state=25
# Accuracy:0.39879262422582273
# Meansquare_error 0.48687995323857847
# RootMeansquare: 0.6977678362023993
# [0.26277721 0.27630962 0.39217925 0.41738287 0.37730703]
# 0.34519119664699066
# Difference Between Accuracy and Cross_val_score mean: 0.05360142757883207
#
# Model:RandomForestRegressor with random_state=25
# Accuracy:0.8657770069000732
# Meansquare_error 0.10869874062985727
# RootMeansquare: 0.3296949205399702
# [0.80821501 0.84437987 0.6739211  0.78241162 0.82727724]
# 0.7872409670007462
# Difference Between Accuracy and Cross_val_score mean: 0.078536039899327
#
# Model:DecisionTreeRegressor with random_state=25
# Accuracy:0.7465953533079279
# Meansquare_error 0.20521644860560906
# RootMeansquare: 0.45300822134439134
# [0.61670333 0.53510662 0.60672878 0.65697421 0.74341604]
# 0.6317857948677875
# Difference Between Accuracy and Cross_val_score mean: 0.1148095584401404
#
# Model:KNeighborsRegressor with random_state=25
# ...

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# Initialize GridSearchCV with the ExtraTreesRegressor and parameter grid
grid_search_etr = GridSearchCV(estimator=et1_reg, param_grid=param_grid, cv=5, n_jobs=-1, scoring='neg_mean_squared_error')

# Fit GridSearchCV to the training data
grid_search_etr.fit(x1_reg_train, y1_reg_train)

# Get the best parameters and best score
best_params_etr = grid_search_etr.best_params_
best_score_etr = grid_search_etr.best_score_

print("Best Parameters for ExtraTreesRegressor:", best_params_etr)
print("Best Score for ExtraTreesRegressor:", best_score_etr)
# Out:
# C:\Users\ganes\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 540 fits failed out of a total of 1620.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 540 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ganes\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ganes\anaconda3\lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ganes\anaconda3\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
et1h_reg=ExtraTreesRegressor(max_depth= 20, max_features= 'log2', min_samples_leaf= 1, min_samples_split= 2, n_estimators= 200)
et1h_reg.fit(x1_reg_train,y1_reg_train)
# Out:
# ExtraTreesRegressor(max_depth=20, max_features='log2', n_estimators=200)

# %%
et1h_reg_pred=et1h_reg.predict(x1_reg_test)

# %%
accuracy=r2_score(y1_reg_test,et1h_reg_pred)
print(f'Accuracy:{accuracy}')
mse=mean_squared_error(y1_reg_test,et1h_reg_pred)
print('Meansquare_error',mse)
print('RootMeansquare:',np.sqrt(mse))
et1h_reg_cross_score=cross_val_score(et1h_reg,x,y,cv=5)
print(et1h_reg_cross_score)
print(et1h_reg_cross_score.mean())
        
difference= accuracy-et1h_reg_cross_score.mean()
print(f'Difference Between Accuracy and Cross_val_score mean: {difference}\n')
# Out:
# Accuracy:0.9401447144850189
# Meansquare_error 0.06939773739980866
# RootMeansquare: 0.26343450305495036
# [0.84280975 0.8763217  0.69844064 0.78804015 0.80637378]
# 0.8023972013012026
# Difference Between Accuracy and Cross_val_score mean: 0.13774751318381628

# %%
import joblib

# %%
joblib.dump(et1_reg,'power_plant_capacity_mw_analysis')
# Out:
# ['power_plant_capacity_mw_analysis']

# %%
model_reg=joblib.load('power_plant_capacity_mw_analysis')
pred_reg=model_reg.predict(x1_reg_test)

# %%
b=np.array(y1_reg_test)
df_test_reg=pd.DataFrame()
df_test_reg['original']=b
df_test_reg['prediction']=pred_reg
df_test_reg
# Out:
#      original  prediction
# 0    0.183572    0.314766
# 1   -0.481196   -0.488202
# 2   -0.486024   -0.473668
# 3   -0.551897   -0.542606
# 4   -0.508786   -0.504888
# ..        ...         ...
# 268 -0.535515   -0.534177
# 269 -0.437223   -0.454519
# 270 -0.524393   -0.532640
# 271  0.136150    0.018569
# 272 -0.536895   -0.535981
#
# [273 rows x 2 columns]
